# %% [markdown]
# Imports

# %%
import xml.etree.ElementTree as ET
import json
from collections import defaultdict

# %% [markdown]
# Helper functions

# %%
from collections import defaultdict


def build_element_tree(root):
    def recursive_build(element):
        if element.tag != 'Item':
            return None
        
        item_id = element.find('ID').text
        name = element.find('Name').text
        description = element.find('Description').text
        
        children = []
        for child in element.find('Children') or []:
            child_tree = recursive_build(child)
            if child_tree:
                children.append(child_tree)
        
        return {
            'id': item_id,
            'children': children,
            'properties': set()
        }

    tree = []
    for item in root.find('.//Items'):
        item_tree = recursive_build(item)
        if item_tree:
            tree.append(item_tree)
    
    return tree

def get_properties(root):
    properties = defaultdict(set)
    for prop_def in root.findall('.//PropertyDefinition'):
        name_elem = prop_def.find('Name')
        if name_elem is not None:
            prop_name = name_elem.text
            for class_id in prop_def.findall('.//ClassificationID/ItemID'):
                if class_id is not None:
                    item_id = class_id.text
                    properties[item_id].add(prop_name)
    return properties

def assign_properties(tree, properties):
    for node in tree:
        if node['id'] in properties:
            node['properties'] = properties[node['id']]
        assign_properties(node['children'], properties)

def sets_to_lists(obj):
    if isinstance(obj, dict):
        return {key: sets_to_lists(value) for key, value in obj.items()}
    elif isinstance(obj, set):
        return list(obj)
    else:
        return obj

# %% [markdown]
# Create tree structure

# %%
# Load the XML file
tree = ET.parse('input.xml')
root = tree.getroot()

# Build the element tree and get properties
element_tree = build_element_tree(root)
print("Element tree created.")

properties = get_properties(root)
assign_properties(element_tree, properties)
print("Properties assigned to element tree.")
with open('entry_tree.json', 'w') as f:
    json.dump(element_tree, f, indent=2, default=lambda x: list(x) if isinstance(x, set) else x)
# Out:
# Element tree created.
# Properties assigned to element tree.
# C:\Users\CDRI\AppData\Local\Temp\ipykernel_17728\3392539100.py:14: DeprecationWarning: Testing an element's truth value will raise an exception in future versions.  Use specific 'len(elem)' or 'elem is not None' test instead.
#   for child in element.find('Children') or []:

# %% [markdown]
# Export existing config (testing purposes)

# %%
def export_config_prev(element_tree):
    def recursive_export(node, parent_properties=None):
        if parent_properties is None:
            parent_properties = set()

        config_node = {
            'id': node['id']
        }

        not_inherited = parent_properties - node['properties']
        if not_inherited and len(node['properties']) > 0:
            config_node['not_inherited_from'] = not_inherited

        new_props = node['properties'] - parent_properties
        if new_props and node['properties'] != parent_properties:
            config_node['new_properties'] = new_props

        # Process children
        all_child_properties = set()
        children = []
        for child in node['children']:
            child_config = recursive_export(child, node['properties'])
            if child_config:
                children.append(child_config)
                all_child_properties |= child_config.get('new_properties', set())
                all_child_properties |= (node['properties'] - child_config.get('not_inherited_from', set()))

        if children:
            config_node['children'] = children

        # Calculate properties that are never inherited to any child
        if node['children']:
            never_inherit = node['properties'] - all_child_properties
            if never_inherit:
                config_node['never_inherit_to'] = never_inherit

        return config_node if len(config_node) > 0 else None

    config_prev = []
    for root_node in element_tree:
        root_config = recursive_export(root_node)
        if root_config:
            config_prev.append(root_config)

    return config_prev

# Usage
config_prev = export_config_prev(element_tree)

# Convert sets to lists for JSON serialization and remove empty lists
def clean_and_convert(obj):
    if isinstance(obj, dict):
        return {k: clean_and_convert(v) for k, v in obj.items() if v}
    elif isinstance(obj, list):
        return [clean_and_convert(v) for v in obj if v]
    elif isinstance(obj, set):
        return list(obj) if obj else None
    else:
        return obj

serializable_config = clean_and_convert(config_prev)

print("Existing configuration extracted:")
print(json.dumps(serializable_config, indent=2))

# Save config_prev to a file
with open('config_prev.json', 'w') as f:
    json.dump(serializable_config, f, indent=2)
# Out:
# Existing configuration extracted:
# [
#   {
#     "id": "Site",
#     "children": [
#       {
#         "id": "Geographic Element",
#         "children": [
#           {
#             "id": "Terrain"
#           },
#           {
#             "id": "Site Geometry"
#           },
#           {
#             "id": "Flora & Fauna"
#           }
#         ]
#       },
#       {
#         "id": "Massing",
#         "children": [
#           {
#             "id": "Morph"
#           }
#         ]
#       },
#       {
#         "id": "Civil Element"
#       }
#     ]
#   },
#   {
#     "id": "Space",
#     "new_properties": [
#       "Fire exit space",
#       "Finishing - Floors",
#       "Finishing - Walls",
#       "Access - accessibility for the disabled",
#       "Wall finish thickness (requirement)",
#       "Risk factor",
#       "Usage type of space",
#       "Status (Space and Zone)",
#       "Number of expected occupants",
#       "Phasing",
#       "Sprinkling",
#       "Documentation",
#       "Finishing - Ceilings",
#       "Access - Accessible to the public",
#       "Finishing - Baseboards",
#       "Passage height required"
#     ],
#     "children": [
#       {
#         "id": "External Space",
#         "children": [
#           {
#             "id": "Parking Space"
#           }
#         ]
#       },
#       {
#         "id": "Internal Space",
#         "children": [
#           {
#             "id": "Access Space"
#           },
#           {
#             "id": "Commercial Space"
#           },
#           {
#             "id": "Communication Space"
#           },
#           {
#             "id": "Cultural Space"
#           },
#           {
#             "id": "Educational Space"
#           },
#           {
#             "id": "Equipment Space"
#           },
#           {
#             "id": "Medical Space"
#           },
#           {
#             "id": "Office Space"
#           },
#           {
#             "id": "Production Space"
#           },
#           {
#             "id": "Recreational Space"
#           },
#           {
#             "id": "Research Space"
#           },
#           {
#             "id": "Residential Space"
#           },
#           {
#             "id": "Storage Space"
#           },
#           {
#             "id": "Transport Space"
#           },
#           {
#             "id": "General Floor Area Space"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "id": "Elements",
#     "children": [
#       {
#         "id": "Construction Element",
#         "children": [
#           {
#             "id": "Building Element Proxy",
#             "children": [
#               {
#                 "id": "Complex Building Element Proxy"
#               },
#               {
#                 "id": "Element Building Element Proxy"
#               },
#               {
#                 "id": "Partial Building Element Proxy"
#               },
#               {
#                 "id": "Provision for Space"
#               },
#               {
#                 "id": "Provision for Void"
#               }
#             ]
#           },
#           {
#             "id": "Wall",
#             "new_properties": [
#               "IFC renovation status",
#               "Phasing",
#               "Thermal Conductivity",
#               "Thermal Transmittance",
#               "Documentation",
#               "Flammability rating",
#               "Construction method",
#               "Fire Resistance Rating",
#               "Reinforcement",
#               "Work package",
#               "Outer shell"
#             ],
#             "children": [
#               {
#                 "id": "Elemented Wall"
#               },
#               {
#                 "id": "Movable Wall"
#               },
#               {
#                 "id": "Parapet Wall"
#               },
#               {
#                 "id": "Partitioning Wall"
#               },
#               {
#                 "id": "Plumbing Wall"
#               },
#               {
#                 "id": "Polygonal Wall"
#               },
#               {
#                 "id": "Shear Wall"
#               },
#               {
#                 "id": "Solid Wall"
#               },
#               {
#                 "id": "Standard Wall"
#               },
#               {
#                 "id": "Thermal break (structural)"
#               },
#               {
#                 "id": "Secant pile"
#               },
#               {
#                 "id": "Tangeant pile"
#               },
#               {
#                 "id": "Sheet pile"
#               },
#               {
#                 "id": "Retaining wall"
#               },
#               {
#                 "id": "Deepwall"
#               },
#               {
#                 "id": "Soldier pile wall"
#               },
#               {
#                 "id": "Combiwall"
#               },
#               {
#                 "id": "Soilmix wall"
#               },
#               {
#                 "id": "Cement-bentonite slurry wall"
#               },
#               {
#                 "id": "Timbered trench"
#               }
#             ]
#           },
#           {
#             "id": "Footing",
#             "children": [
#               {
#                 "id": "Caisson Foundation"
#               },
#               {
#                 "id": "Footing Beam",
#                 "new_properties": [
#                   "IFC renovation status",
#                   "Phasing",
#                   "Thermal Conductivity",
#                   "Documentation",
#                   "Construction method",
#                   "Reinforcement",
#                   "Work package",
#                   "Structural Function ArchiCAD - IsLoadBearing"
#                 ]
#               },
#               {
#                 "id": "Pad Footing"
#               },
#               {
#                 "id": "Pile Cap"
#               },
#               {
#                 "id": "Strip Footing",
#                 "new_properties": [
#                   "IFC renovation status",
#                   "Phasing",
#                   "Thermal Conductivity",
#                   "Documentation",
#                   "Construction method",
#                   "Reinforcement",
#                   "Work package",
#                   "Structural Function ArchiCAD - IsLoadBearing"
#                 ]
#               }
#             ]
#           },
#           {
#             "id": "Column",
#             "new_properties": [
#               "IFC renovation status",
#               "Phasing",
#               "Thermal Conductivity",
#               "Documentation",
#               "Flammability rating",
#               "Construction method",
#               "Fire Resistance Rating",
#               "Reinforcement",
#               "Work package",
#               "Outer shell"
#             ],
#             "children": [
#               {
#                 "id": "Column Segment"
#               },
#               {
#                 "id": "Pilaster"
#               }
#             ]
#           },
#           {
#             "id": "Pile",
#             "new_properties": [
#               "IFC renovation status",
#               "Phasing",
#               "Thermal Conductivity",
#               "Documentation",
#               "Construction method",
#               "Reinforcement",
#               "Work package",
#               "Structural Function ArchiCAD - IsLoadBearing"
#             ],
#             "children": [
#               {
#                 "id": "Bored Pile"
#               },
#               {
#                 "id": "Cohesion Pile"
#               },
#               {
#                 "id": "Driven Pile"
#               },
#               {
#                 "id": "Friction Pile"
#               },
#               {
#                 "id": "Jetgrouting Pile"
#               },
#               {
#                 "id": "Support Pile"
#               },
#               {
#                 "id": "Screw Pile"
#               },
#               {
#                 "id": "Soil Mix"
#               },
#               {
#                 "id": "Stone columns"
#               },
#               {
#                 "id": "Rigid inclusions"
#               }
#             ]
#           },
#           {
#             "id": "Beam",
#             "new_properties": [
#               "IFC renovation status",
#               "Phasing",
#               "Thermal Conductivity",
#               "Thermal Transmittance",
#               "Documentation",
#               "Flammability rating",
#               "Construction method",
#               "Fire Resistance Rating",
#               "Reinforcement",
#               "Work package",
#               "Outer shell"
#             ],
#             "children": [
#               {
#                 "id": "Beam Segment"
#               },
#               {
#                 "id": "Joist"
#               },
#               {
#                 "id": "Hollowcore"
#               },
#               {
#                 "id": "Lintel"
#               },
#               {
#                 "id": "Spandrel"
#               },
#               {
#                 "id": "T-Beam"
#               },
#               {
#                 "id": "Ring beam"
#               },
#               {
#                 "id": "Spandrel beam"
#               }
#             ]
#           },
#           {
#             "id": "Slab",
#             "new_properties": [
#               "Phasing",
#               "Thermal Conductivity",
#               "Thermal Transmittance",
#               "Documentation",
#               "Construction method",
#               "Fire Resistance Rating",
#               "Reinforcement",
#               "Work package",
#               "Outer shell"
#             ],
#             "children": [
#               {
#                 "id": "Floor Slab"
#               },
#               {
#                 "id": "Roof Slab"
#               },
#               {
#                 "id": "Landing Slab"
#               },
#               {
#                 "id": "Base Slab",
#                 "not_inherited_from": [
#                   "Fire Resistance Rating"
#                 ],
#                 "new_properties": [
#                   "IFC renovation status"
#                 ]
#               }
#             ]
#           },
#           {
#             "id": "Roof",
#             "new_properties": [
#               "IFC renovation status",
#               "Phasing",
#               "Thermal Conductivity",
#               "Thermal Transmittance",
#               "Documentation",
#               "Flammability rating",
#               "Construction method",
#               "Fire Resistance Rating",
#               "Reinforcement",
#               "Work package",
#               "Outer shell",
#               "Structural Function ArchiCAD - IsLoadBearing"
#             ],
#             "children": [
#               {
#                 "id": "Flat Roof"
#               },
#               {
#                 "id": "Shed Roof"
#               },
#               {
#                 "id": "Gable Roof"
#               },
#               {
#                 "id": "Hip Roof"
#               },
#               {
#                 "id": "Hipped Gable Roof"
#               },
#               {
#                 "id": "Gambrel Roof"
#               },
#               {
#                 "id": "Mansard Roof"
#               },
#               {
#                 "id": "Barrel Roof"
#               },
#               {
#                 "id": "Rainbow Roof"
#               },
#               {
#                 "id": "Butterfly Roof"
#               },
#               {
#                 "id": "Pavilion Roof"
#               },
#               {
#                 "id": "Dome Roof"
#               },
#               {
#                 "id": "Freeform Roof"
#               },
#               {
#                 "id": "Pergola"
#               }
#             ]
#           },
#           {
#             "id": "Shell"
#           },
#           {
#             "id": "Covering",
#             "children": [
#               {
#                 "id": "Ceiling",
#                 "new_properties": [
#                   "IFC renovation status",
#                   "Phasing",
#                   "Thermal Conductivity",
#                   "Thermal Transmittance",
#                   "Documentation",
#                   "Flammability rating",
#                   "Fire Resistance Rating",
#                   "Transmission acoustique",
#                   "Work package",
#                   "Outer shell"
#                 ]
#               },
#               {
#                 "id": "Cladding",
#                 "new_properties": [
#                   "IFC renovation status",
#                   "Phasing",
#                   "Thermal Conductivity",
#                   "Thermal Transmittance",
#                   "Documentation",
#                   "Flammability rating",
#                   "Fire Resistance Rating",
#                   "Transmission acoustique",
#                   "Work package",
#                   "Outer shell"
#                 ]
#               },
#               {
#                 "id": "Flooring",
#                 "new_properties": [
#                   "IFC renovation status",
#                   "Phasing",
#                   "Thermal Conductivity",
#                   "Thermal Transmittance",
#                   "Documentation",
#                   "Flammability rating",
#                   "Fire Resistance Rating",
#                   "Transmission acoustique",
#                   "Work package",
#                   "Outer shell"
#                 ]
#               },
#               {
#                 "id": "Insulation"
#               },
#               {
#                 "id": "Membrane"
#               },
#               {
#                 "id": "Molding"
#               },
#               {
#                 "id": "Roofing",
#                 "new_properties": [
#                   "IFC renovation status",
#                   "Phasing",
#                   "Thermal Conductivity",
#                   "Thermal Transmittance",
#                   "Documentation",
#                   "Flammability rating",
#                   "Fire Resistance Rating",
#                   "Transmission acoustique",
#                   "Work package",
#                   "Outer shell"
#                 ]
#               },
#               {
#                 "id": "Sleeving"
#               },
#               {
#                 "id": "Skirtingboard"
#               },
#               {
#                 "id": "Wrapping"
#               },
#               {
#                 "id": "Technical Floor"
#               },
#               {
#                 "id": "False ceiling"
#               },
#               {
#                 "id": "Wall protection"
#               },
#               {
#                 "id": "Wall painting"
#               },
#               {
#                 "id": "Floor paint"
#               },
#               {
#                 "id": "Ceiling paint"
#               }
#             ]
#           },
#           {
#             "id": "Stair",
#             "new_properties": [
#               "IFC renovation status",
#               "Phasing",
#               "Thermal Conductivity",
#               "Thermal Transmittance",
#               "Work package",
#               "Documentation",
#               "Flammability rating",
#               "Fire Resistance Rating",
#               "Place of assembly of the staircase",
#               "Fire Exit",
#               "Outer shell"
#             ],
#             "children": [
#               {
#                 "id": "Stair Finish",
#                 "children": [
#                   {
#                     "id": "Stair Riser"
#                   },
#                   {
#                     "id": "Stair Tread"
#                   }
#                 ]
#               },
#               {
#                 "id": "Stair Structure",
#                 "children": [
#                   {
#                     "id": "Stair Flight",
#                     "children": [
#                       {
#                         "id": "Curved Stair Flight"
#                       },
#                       {
#                         "id": "Freeform Stair Flight"
#                       },
#                       {
#                         "id": "Spiral Stair Flight"
#                       },
#                       {
#                         "id": "Straight Stair Flight"
#                       },
#                       {
#                         "id": "Winder Stair Flight"
#                       }
#                     ]
#                   },
#                   {
#                     "id": "Stair Landing"
#                   }
#                 ]
#               },
#               {
#                 "id": "Stair Layout",
#                 "children": [
#                   {
#                     "id": "Curved-run Stair"
#                   },
#                   {
#                     "id": "Double-return Stair"
#                   },
#                   {
#                     "id": "Half-turn Stair"
#                   },
#                   {
#                     "id": "Half-winding Stair"
#                   },
#                   {
#                     "id": "Quarter-turn Stair"
#                   },
#                   {
#                     "id": "Quarter-winding Stair"
#                   },
#                   {
#                     "id": "Spiral Stair"
#                   },
#                   {
#                     "id": "Straight-run Stair"
#                   },
#                   {
#                     "id": "Three-quarter-turn Stair"
#                   },
#                   {
#                     "id": "Three-quarter-winding Stair"
#                   },
#                   {
#                     "id": "Two-curved-run Stair"
#                   },
#                   {
#                     "id": "Two-quarter-turn Stair"
#                   },
#                   {
#                     "id": "Two-quarter-winding Stair"
#                   },
#                   {
#                     "id": "Two-straight-run Stair"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "id": "Ramp",
#             "new_properties": [
#               "IFC renovation status",
#               "Phasing",
#               "Thermal Conductivity",
#               "Documentation",
#               "Flammability rating",
#               "Construction method",
#               "Fire Resistance Rating",
#               "Reinforcement",
#               "Work package",
#               "Outer shell"
#             ],
#             "children": [
#               {
#                 "id": "Ramp Flight",
#                 "children": [
#                   {
#                     "id": "Spiral Ramp Flight"
#                   },
#                   {
#                     "id": "Straight Ramp Flight"
#                   }
#                 ]
#               },
#               {
#                 "id": "Ramp Landing"
#               },
#               {
#                 "id": "Half-turn Ramp"
#               },
#               {
#                 "id": "Quarter-turn Ramp"
#               },
#               {
#                 "id": "Spiral Ramp"
#               },
#               {
#                 "id": "Straight-run Ramp"
#               },
#               {
#                 "id": "Two-quarter-turn Ramp"
#               },
#               {
#                 "id": "Two-straight-run Ramp"
#               }
#             ]
#           },
#           {
#             "id": "Railing",
#             "children": [
#               {
#                 "id": "Rail",
#                 "children": [
#                   {
#                     "id": "Handrail"
#                   },
#                   {
#                     "id": "Guardrail"
#                   }
#                 ]
#               },
#               {
#                 "id": "Railing Post"
#               },
#               {
#                 "id": "Railing Panel"
#               },
#               {
#                 "id": "Balustrade"
#               }
#             ]
#           },
#           {
#             "id": "Curtain Wall",
#             "new_properties": [
#               "IFC renovation status",
#               "Phasing",
#               "Thermal Transmittance",
#               "Documentation",
#               "Flammability rating",
#               "Fire Resistance Rating",
#               "Work package",
#               "Outer shell"
#             ],
#             "children": [
#               {
#                 "id": "Curtain Wall Panel"
#               },
#               {
#                 "id": "Curtain Wall Frame"
#               }
#             ]
#           },
#           {
#             "id": "Member",
#             "new_properties": [
#               "IFC renovation status",
#               "Phasing",
#               "Thermal Conductivity",
#               "Thermal Transmittance",
#               "Documentation",
#               "Flammability rating",
#               "Construction method",
#               "Fire Resistance Rating",
#               "Reinforcement",
#               "Work package",
#               "Outer shell"
#             ],
#             "children": [
#               {
#                 "id": "Brace"
#               },
#               {
#                 "id": "Chord"
#               },
#               {
#                 "id": "Collar"
#               },
#               {
#                 "id": "Mullion"
#               },
#               {
#                 "id": "Plate Member"
#               },
#               {
#                 "id": "Post"
#               },
#               {
#                 "id": "Purlin"
#               },
#               {
#                 "id": "Rafter"
#               },
#               {
#                 "id": "Stringer"
#               },
#               {
#                 "id": "Strut"
#               },
#               {
#                 "id": "Stud"
#               },
#               {
#                 "id": "Floor joist"
#               }
#             ]
#           },
#           {
#             "id": "Plate",
#             "children": [
#               {
#                 "id": "Curtain Panel"
#               },
#               {
#                 "id": "Sheet"
#               }
#             ]
#           },
#           {
#             "id": "Shading Device",
#             "children": [
#               {
#                 "id": "Awning"
#               },
#               {
#                 "id": "Jalousie"
#               },
#               {
#                 "id": "Shutter"
#               }
#             ]
#           },
#           {
#             "id": "Chimney",
#             "new_properties": [
#               "IFC renovation status",
#               "Phasing",
#               "Condition - Condition evaluation",
#               "Chimney: Number of pipes",
#               "Documentation",
#               "Condition - Date of assessment",
#               "Guarantee - finishing date of Guarantee",
#               "Work package"
#             ]
#           }
#         ]
#       },
#       {
#         "id": "Opening",
#         "children": [
#           {
#             "id": "Door",
#             "new_properties": [
#               "Ventilation gap surface",
#               "Thermal Transmittance",
#               "Glazing - Solar transmission",
#               "Glazing - Glazed area ratio",
#               "Access - accessibility for the disabled",
#               "Has Sill Internal",
#               "Security Rating",
#               "Access control",
#               "Motorized opening",
#               "Condition - Date of assessment",
#               "Flammability rating",
#               "Work package",
#               "Fire Exit",
#               "BulletProof",
#               "Window shading - Portable",
#               "IFC renovation status",
#               "Glazing - Type (single=1-double=2-triple=3-quadruple=4)",
#               "Phasing",
#               "Window shading - Automatic",
#               "Condition - Condition evaluation",
#               "Has Sill External",
#               "Type of blackout device",
#               "Passage width",
#               "Documentation",
#               "Fire Resistance Rating",
#               "Transmission acoustique",
#               "Guarantee - finishing date of Guarantee",
#               "Outer shell"
#             ],
#             "children": [
#               {
#                 "id": "Gate"
#               },
#               {
#                 "id": "Trapdoor"
#               }
#             ]
#           },
#           {
#             "id": "Window",
#             "new_properties": [
#               "Ventilation gap surface",
#               "Thermal Transmittance",
#               "Glazing - Solar transmission",
#               "Glazing - Glazed area ratio",
#               "Security Rating",
#               "Has Sill Internal",
#               "Flammability rating",
#               "Motorized opening",
#               "Condition - Date of assessment",
#               "Opening type",
#               "Work package",
#               "Fire Exit",
#               "BulletProof",
#               "Window shading - Portable",
#               "IFC renovation status",
#               "Glazing - Type (single=1-double=2-triple=3-quadruple=4)",
#               "Phasing",
#               "Window shading - Automatic",
#               "Condition - Condition evaluation",
#               "Has Sill External",
#               "Type of blackout device",
#               "Passage width",
#               "Documentation",
#               "Fire Resistance Rating",
#               "Transmission acoustique",
#               "Guarantee - finishing date of Guarantee",
#               "Outer shell"
#             ],
#             "children": [
#               {
#                 "id": "Lightdome"
#               },
#               {
#                 "id": "Skylight"
#               }
#             ]
#           },
#           {
#             "id": "Recess"
#           },
#           {
#             "id": "Empty Opening"
#           }
#         ]
#       },
#       {
#         "id": "Element Component",
#         "children": [
#           {
#             "id": "Discrete Accessory",
#             "children": [
#               {
#                 "id": "Anchorplate"
#               },
#               {
#                 "id": "Bracket"
#               },
#               {
#                 "id": "Shoe"
#               }
#             ]
#           },
#           {
#             "id": "Fastener",
#             "children": [
#               {
#                 "id": "Mechanical Fastener",
#                 "children": [
#                   {
#                     "id": "Anchorbolt"
#                   },
#                   {
#                     "id": "Bolt"
#                   },
#                   {
#                     "id": "Dowel"
#                   },
#                   {
#                     "id": "Nail"
#                   },
#                   {
#                     "id": "Nailplate"
#                   },
#                   {
#                     "id": "Rivet"
#                   },
#                   {
#                     "id": "Screw"
#                   },
#                   {
#                     "id": "Shear Connector"
#                   },
#                   {
#                     "id": "Staple"
#                   },
#                   {
#                     "id": "Stud Shear Connector"
#                   }
#                 ]
#               },
#               {
#                 "id": "Glue"
#               },
#               {
#                 "id": "Mortar Fastener"
#               },
#               {
#                 "id": "Weld"
#               }
#             ]
#           },
#           {
#             "id": "Reinforcement",
#             "children": [
#               {
#                 "id": "Reinforcing Bar",
#                 "children": [
#                   {
#                     "id": "Anchoring Reinforcing Bar"
#                   },
#                   {
#                     "id": "Edge Reinforcing Bar"
#                   },
#                   {
#                     "id": "Ligature Reinforcing Bar"
#                   },
#                   {
#                     "id": "Main Reinforcing Bar"
#                   },
#                   {
#                     "id": "Punching Reinforcing Bar"
#                   },
#                   {
#                     "id": "Ring Reinforcing Bar"
#                   },
#                   {
#                     "id": "Shear Reinforcing Bar"
#                   },
#                   {
#                     "id": "Stud Reinforcing Bar"
#                   }
#                 ]
#               },
#               {
#                 "id": "Reinforcing Mesh"
#               },
#               {
#                 "id": "Tendon",
#                 "children": [
#                   {
#                     "id": "Bar Tendon"
#                   },
#                   {
#                     "id": "Coated Tendon"
#                   },
#                   {
#                     "id": "Strand Tendon"
#                   },
#                   {
#                     "id": "Wire Tendon"
#                   }
#                 ]
#               },
#               {
#                 "id": "Tendon Anchor",
#                 "children": [
#                   {
#                     "id": "Coupler Tendon Anchor"
#                   },
#                   {
#                     "id": "Fixed-end Tendon Anchor"
#                   },
#                   {
#                     "id": "Tensioning-end Tendon Anchor"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "id": "Vibration Isolator",
#             "children": [
#               {
#                 "id": "Compression"
#               },
#               {
#                 "id": "Spring"
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "id": "Furnishing",
#         "children": [
#           {
#             "id": "Furniture",
#             "new_properties": [
#               "IFC renovation status",
#               "Phasing",
#               "physically attached (yes/no)",
#               "Condition - Condition evaluation",
#               "Documentation",
#               "Cabinet with lock (yes/no)",
#               "Condition - Date of assessment",
#               "Guarantee - finishing date of Guarantee",
#               "Work package",
#               "Description"
#             ],
#             "children": [
#               {
#                 "id": "Bed"
#               },
#               {
#                 "id": "Chair"
#               },
#               {
#                 "id": "Desk"
#               },
#               {
#                 "id": "Filecabinet"
#               },
#               {
#                 "id": "Shelf"
#               },
#               {
#                 "id": "Sofa"
#               },
#               {
#                 "id": "Table"
#               },
#               {
#                 "id": "Kitchen furniture"
#               },
#               {
#                 "id": "Planter"
#               }
#             ]
#           },
#           {
#             "id": "System Furniture",
#             "children": [
#               {
#                 "id": "System Furniture Panel"
#               },
#               {
#                 "id": "Work Surface"
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "id": "MEP Element",
#         "children": [
#           {
#             "id": "Distribution Control Element",
#             "children": [
#               {
#                 "id": "Actuator",
#                 "children": [
#                   {
#                     "id": "Electric Actuator"
#                   },
#                   {
#                     "id": "Handoperated Actuator"
#                   },
#                   {
#                     "id": "Hydraulic Actuator"
#                   },
#                   {
#                     "id": "Pneumatic Actuator"
#                   },
#                   {
#                     "id": "Thermostatic Actuator"
#                   }
#                 ]
#               },
#               {
#                 "id": "Alarm",
#                 "children": [
#                   {
#                     "id": "Bell Alarm"
#                   },
#                   {
#                     "id": "Break Glass Button Alarm"
#                   },
#                   {
#                     "id": "Light Alarm"
#                   },
#                   {
#                     "id": "Manual Pull Box Alarm"
#                   },
#                   {
#                     "id": "Siren Alarm"
#                   },
#                   {
#                     "id": "Whistle Alarm"
#                   }
#                 ]
#               },
#               {
#                 "id": "Controller",
#                 "children": [
#                   {
#                     "id": "Floating Controller"
#                   },
#                   {
#                     "id": "Multiposition Controller"
#                   },
#                   {
#                     "id": "Programmable Controller"
#                   },
#                   {
#                     "id": "Proportional Controller"
#                   },
#                   {
#                     "id": "Two Position Controller"
#                   }
#                 ]
#               },
#               {
#                 "id": "Flow Instrument",
#                 "children": [
#                   {
#                     "id": "Ammeter"
#                   },
#                   {
#                     "id": "Frequency Meter"
#                   },
#                   {
#                     "id": "Phase Angle Meter"
#                   },
#                   {
#                     "id": "Power Factor Meter"
#                   },
#                   {
#                     "id": "Pressure Gauge"
#                   },
#                   {
#                     "id": "Thermometer"
#                   },
#                   {
#                     "id": "Voltmeter Peak"
#                   },
#                   {
#                     "id": "Voltmeter RMS"
#                   }
#                 ]
#               },
#               {
#                 "id": "Protective Device Tripping Unit",
#                 "children": [
#                   {
#                     "id": "Electromagnetic Protective Device"
#                   },
#                   {
#                     "id": "Electronic Protective Device"
#                   },
#                   {
#                     "id": "Residual Current Protective Device"
#                   },
#                   {
#                     "id": "Thermal Protective Device"
#                   }
#                 ]
#               },
#               {
#                 "id": "Sensor",
#                 "children": [
#                   {
#                     "id": "CO2 Sensor"
#                   },
#                   {
#                     "id": "Conductance Sensor"
#                   },
#                   {
#                     "id": "Contact Sensor"
#                   },
#                   {
#                     "id": "CO Sensor"
#                   },
#                   {
#                     "id": "Fire Sensor"
#                   },
#                   {
#                     "id": "Flow Sensor"
#                   },
#                   {
#                     "id": "Frost Sensor"
#                   },
#                   {
#                     "id": "Gas Sensor"
#                   },
#                   {
#                     "id": "Heat Sensor"
#                   },
#                   {
#                     "id": "Humidity Sensor"
#                   },
#                   {
#                     "id": "Identifier Sensor"
#                   },
#                   {
#                     "id": "Ionconcentration Sensor"
#                   },
#                   {
#                     "id": "Level Sensor"
#                   },
#                   {
#                     "id": "Light Sensor"
#                   },
#                   {
#                     "id": "Moisture Sensor"
#                   },
#                   {
#                     "id": "Movement Sensor"
#                   },
#                   {
#                     "id": "PH Sensor"
#                   },
#                   {
#                     "id": "Pressure Sensor"
#                   },
#                   {
#                     "id": "Radiation Sensor"
#                   },
#                   {
#                     "id": "Radioactivity Sensor"
#                   },
#                   {
#                     "id": "Smoke Sensor"
#                   },
#                   {
#                     "id": "Sound Sensor"
#                   },
#                   {
#                     "id": "Temperature Sensor"
#                   },
#                   {
#                     "id": "Wind Sensor"
#                   }
#                 ]
#               },
#               {
#                 "id": "Unitary Control Element",
#                 "children": [
#                   {
#                     "id": "Alarm Panel"
#                   },
#                   {
#                     "id": "Control Panel"
#                   },
#                   {
#                     "id": "Gas Detection Panel"
#                   },
#                   {
#                     "id": "Humidistat"
#                   },
#                   {
#                     "id": "Indicator Panel"
#                   },
#                   {
#                     "id": "Mimic Panel"
#                   },
#                   {
#                     "id": "Thermostat"
#                   },
#                   {
#                     "id": "Weather Station"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "id": "Distribution Flow Element",
#             "children": [
#               {
#                 "id": "Distribution Chamber Element",
#                 "children": [
#                   {
#                     "id": "Formed Duct"
#                   },
#                   {
#                     "id": "Inspection Chamber"
#                   },
#                   {
#                     "id": "Inspection Pit"
#                   },
#                   {
#                     "id": "Manhole"
#                   },
#                   {
#                     "id": "Meter Chamber"
#                   },
#                   {
#                     "id": "Sump"
#                   },
#                   {
#                     "id": "Trench"
#                   },
#                   {
#                     "id": "Valve Chamber"
#                   }
#                 ]
#               },
#               {
#                 "id": "Energy Conversion Device",
#                 "children": [
#                   {
#                     "id": "Air to Air Heat Recovery",
#                     "children": [
#                       {
#                         "id": "Fixed-Plate Counter-Flow Exchanger"
#                       },
#                       {
#                         "id": "Fixed-Plate Cross-Flow Exchanger"
#                       },
#                       {
#                         "id": "Fixed-Plate Parallel-Flow Exchanger"
#                       },
#                       {
#                         "id": "Heat Pipe"
#                       },
#                       {
#                         "id": "Rotary Wheel Heat Recovery"
#                       },
#                       {
#                         "id": "Run-Around Coil Loop"
#                       },
#                       {
#                         "id": "Thermosiphon Coiltype Heat Exchanger"
#                       },
#                       {
#                         "id": "Thermosiphon Sealed Tube Heat Exchanger"
#                       },
#                       {
#                         "id": "Twin Tower Enthalpy Recovery Loop"
#                       }
#                     ]
#                   },
#                   {
#                     "id": "Boiler",
#                     "children": [
#                       {
#                         "id": "Steam Boiler"
#                       },
#                       {
#                         "id": "Water Boiler"
#                       }
#                     ]
#                   },
#                   {
#                     "id": "Burner"
#                   },
#                   {
#                     "id": "Chiller",
#                     "children": [
#                       {
#                         "id": "Air Cooled Chiller"
#                       },
#                       {
#                         "id": "Heat Recovery Chiller"
#                       },
#                       {
#                         "id": "Water Cooled Chiller"
#                       }
#                     ]
#                   },
#                   {
#                     "id": "Coil",
#                     "children": [
#                       {
#                         "id": "DX Cooling Coil"
#                       },
#                       {
#                         "id": "Electric Heating Coil"
#                       },
#                       {
#                         "id": "Gas Heating Coil"
#                       },
#                       {
#                         "id": "Hydronic Coil"
#                       },
#                       {
#                         "id": "Steam Heating Coil"
#                       },
#                       {
#                         "id": "Water Cooling Coil"
#                       },
#                       {
#                         "id": "Water Heating Coil"
#                       }
#                     ]
#                   },
#                   {
#                     "id": "Condenser",
#                     "children": [
#                       {
#                         "id": "Air Cooled Condenser"
#                       },
#                       {
#                         "id": "Evaporative Cooled Condenser"
#                       },
#                       {
#                         "id": "Water Cooled Condenser"
#                       },
#                       {
#                         "id": "Water Cooled Brazed Plate Condenser"
#                       },
#                       {
#                         "id": "Water Cooled Shell Coil Condenser"
#                       },
#                       {
#                         "id": "Water Cooled Shell Tube Condenser"
#                       },
#                       {
#                         "id": "Water Cooled Tube in Tube Condenser"
#                       }
#                     ]
#                   },
#                   {
#                     "id": "Cooled Beam",
#                     "children": [
#                       {
#                         "id": "Active Cooled Beam"
#                       },
#                       {
#                         "id": "Passive Cooled Beam"
#                       }
#                     ]
#                   },
#                   {
#                     "id": "Cooling Tower",
#                     "children": [
#                       {
#                         "id": "Mechanical Forced-Draft Cooling Tower"
#                       },
#                       {
#                         "id": "Mechanical Induced-Draft Cooling Tower"
#                       },
#                       {
#                         "id": "Natural Draft Cooling Tower"
#                       }
#                     ]
#                   },
#                   {
#                     "id": "Electric Generator",
#                     "children": [
#                       {
#                         "id": "CHP"
#                       },
#                       {
#                         "id": "Engine Generator"
#                       },
#                       {
#                         "id": "Standalone Electric Generator"
#                       }
#                     ]
#                   },
#                   {
#                     "id": "Electric Motor",
#                     "children": [
#                       {
#                         "id": "DC Electric Motor"
#                       },
#                       {
#                         "id": "Induction Electric Motor"
#                       },
#                       {
#                         "id": "Polyphase Electric Motor"
#                       },
#                       {
#                         "id": "Reluctance Synchronous Electric Motor"
#                       },
#                       {
#                         "id": "Synchronous Electric Motor"
#                       }
#                     ]
#                   },
#                   {
#                     "id": "Engine",
#                     "children": [
#                       {
#                         "id": "External Combustion Engine"
#                       },
#                       {
#                         "id": "Internal Combustion Engine"
#                       }
#                     ]
#                   },
#                   {
#                     "id": "Evaporative Cooler",
#                     "children": [
#                       {
#                         "id": "Direct Evaporative Air Washer"
#                       },
#                       {
#                         "id": "Direct Evaporative Packaged Rotary Air Cooler"
#                       },
#                       {
#                         "id": "Direct Evaporative Random Media Air Cooler"
#                       },
#                       {
#                         "id": "Direct Evaporative Rigid Media Air Cooler"
#                       },
#                       {
#                         "id": "Direct Evaporative Slingers Packaged Air Cooler"
#                       },
#                       {
#                         "id": "Indirect Direct Combination"
#                       },
#                       {
#                         "id": "Indirect Evaporative Cooling Tower"
#                       },
#                       {
#                         "id": "Indirect Evaporative Package Air Cooler"
#                       },
#                       {
#                         "id": "Indirect Evaporative Wet Coil"
#                       }
#                     ]
#                   },
#                   {
#                     "id": "Evaporator",
#                     "children": [
#                       {
#                         "id": "Direct Expansion Evaporator"
#                       },
#                       {
#                         "id": "Direct Expansion Brazed Plate Evaporator"
#                       },
#                       {
#                         "id": "Direct Expansion Shell and Tube Evaporator"
#                       },
#                       {
#                         "id": "Direct Expansion Tube in Tube Evaporator"
#                       },
#                       {
#                         "id": "Flooded Shell and Tube Evaporator"
#                       },
#                       {
#                         "id": "Shell and Coil Evaporator"
#                       }
#                     ]
#                   },
#                   {
#                     "id": "Heat Exchanger",
#                     "children": [
#                       {
#                         "id": "Plate Heat Exchanger"
#                       },
#                       {
#                         "id": "Shell and Tube Heat Exchanger"
#                       }
#                     ]
#                   },
#                   {
#                     "id": "Humidifier",
#                     "children": [
#                       {
#                         "id": "Adiabatic Air Washer"
#                       },
#                       {
#                         "id": "Adiabatic Atomizing Humidifier"
#                       },
#                       {
#                         "id": "Adiabatic Compressed Air Nozzle"
#                       },
#                       {
#                         "id": "Adiabatic Pan"
#                       },
#                       {
#                         "id": "Adiabatic Rigid Media"
#                       },
#                       {
#                         "id": "Adiabatic Ultrasonic Humidifier"
#                       },
#                       {
#                         "id": "Adiabatic Wetted Element"
#                       },
#                       {
#                         "id": "Assisted Butane Humidifier"
#                       },
#                       {
#                         "id": "Assisted Electric Humidifier"
#                       },
#                       {
#                         "id": "Assisted Natural Gas Humidifier"
#                       },
#                       {
#                         "id": "Assisted Propane Humidifier"
#                       },
#                       {
#                         "id": "Assisted Steam Humidifier"
#                       },
#                       {
#                         "id": "Steam Injection Humidifier"
#                       }
#                     ]
#                   },
#                   {
#                     "id": "Motor Connection",
#                     "children": [
#                       {
#                         "id": "Belt Drive Motor Connection"
#                       },
#                       {
#                         "id": "Coupling Motor Connection"
#                       },
#                       {
#                         "id": "Direct Drive Motor Connection"
#                       }
#                     ]
#                   },
#                   {
#                     "id": "Solar Device",
#                     "children": [
#                       {
#                         "id": "Solar Collector"
#                       },
#                       {
#                         "id": "Solar Panel"
#                       },
#                       {
#                         "id": "Hybrid solar panel"
#                       }
#                     ]
#                   },
#                   {
# ...
#                       },
#                       {
#                         "id": "Telephone Outlet"
#                       },
#                       {
#                         "id": "Charging station"
#                       }
#                     ]
#                   },
#                   {
#                     "id": "Sanitary Terminal",
#                     "new_properties": [
#                       "IFC renovation status",
#                       "Phasing",
#                       "Capacity (volume)",
#                       "Is automatic",
#                       "Condition - Condition evaluation",
#                       "Documentation",
#                       "Condition - Date of assessment",
#                       "Guarantee - finishing date of Guarantee",
#                       "Type of manipulation",
#                       "Work package"
#                     ],
#                     "children": [
#                       {
#                         "id": "Bath"
#                       },
#                       {
#                         "id": "Bidet"
#                       },
#                       {
#                         "id": "Cistern"
#                       },
#                       {
#                         "id": "Sanitary Fountain"
#                       },
#                       {
#                         "id": "Shower"
#                       },
#                       {
#                         "id": "Sink"
#                       },
#                       {
#                         "id": "Toilet Pan"
#                       },
#                       {
#                         "id": "Urinal"
#                       },
#                       {
#                         "id": "Wash-hand Basin"
#                       },
#                       {
#                         "id": "WC Seat"
#                       }
#                     ]
#                   },
#                   {
#                     "id": "Space Heater",
#                     "children": [
#                       {
#                         "id": "Convector"
#                       },
#                       {
#                         "id": "Radiator"
#                       }
#                     ]
#                   },
#                   {
#                     "id": "Stack Terminal",
#                     "children": [
#                       {
#                         "id": "Bird Cage"
#                       },
#                       {
#                         "id": "Cowl"
#                       },
#                       {
#                         "id": "Rainwater Hopper"
#                       }
#                     ]
#                   },
#                   {
#                     "id": "Waste Terminal",
#                     "children": [
#                       {
#                         "id": "Floor Trap"
#                       },
#                       {
#                         "id": "Floor Waste"
#                       },
#                       {
#                         "id": "Gully Sump"
#                       },
#                       {
#                         "id": "Gully Trap"
#                       },
#                       {
#                         "id": "Roof Drain"
#                       },
#                       {
#                         "id": "Waste Disposal Unit"
#                       },
#                       {
#                         "id": "Waste Trap"
#                       }
#                     ]
#                   }
#                 ]
#               },
#               {
#                 "id": "Flow Treatment Device",
#                 "children": [
#                   {
#                     "id": "Duct Silencer",
#                     "children": [
#                       {
#                         "id": "Flat Oval"
#                       },
#                       {
#                         "id": "Rectangular"
#                       },
#                       {
#                         "id": "Round"
#                       }
#                     ]
#                   },
#                   {
#                     "id": "Filter",
#                     "children": [
#                       {
#                         "id": "Air Particle Filter"
#                       },
#                       {
#                         "id": "Compressed Air Filter"
#                       },
#                       {
#                         "id": "Odor Filter"
#                       },
#                       {
#                         "id": "Oil Filter"
#                       },
#                       {
#                         "id": "Strainer Filter"
#                       },
#                       {
#                         "id": "Water Filter"
#                       }
#                     ]
#                   },
#                   {
#                     "id": "Interceptor",
#                     "children": [
#                       {
#                         "id": "Cyclonic Interceptor"
#                       },
#                       {
#                         "id": "Grease Interceptor"
#                       },
#                       {
#                         "id": "Oil Interceptor"
#                       },
#                       {
#                         "id": "Petrol Interceptor"
#                       }
#                     ]
#                   }
#                 ]
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "id": "Transport Element",
#         "children": [
#           {
#             "id": "Elevator"
#           },
#           {
#             "id": "Escalator"
#           },
#           {
#             "id": "Moving Walkway"
#           },
#           {
#             "id": "Craneway"
#           },
#           {
#             "id": "Lifting Gear"
#           },
#           {
#             "id": "Stair lift"
#           },
#           {
#             "id": "Rubble chute"
#           },
#           {
#             "id": "Facade gondola"
#           },
#           {
#             "id": "Laundry chute"
#           },
#           {
#             "id": "Boarding bridge"
#           },
#           {
#             "id": "Lifting platform"
#           },
#           {
#             "id": "Pneumatic tube system"
#           },
#           {
#             "id": "Escape slide"
#           }
#         ]
#       }
#     ]
#   },
#   {
#     "id": "Components",
#     "children": [
#       {
#         "id": "Structural"
#       },
#       {
#         "id": "Filler"
#       },
#       {
#         "id": "Insulation Component"
#       },
#       {
#         "id": "Airgap"
#       },
#       {
#         "id": "Cladding Component"
#       },
#       {
#         "id": "Finishes"
#       }
#     ]
#   },
#   {
#     "id": "Materials",
#     "children": [
#       {
#         "id": "Generic Material",
#         "children": [
#           {
#             "id": "Generic Structural Material",
#             "children": [
#               {
#                 "id": "Generic Prefabricated Material"
#               },
#               {
#                 "id": "Generic In-situ Material"
#               }
#             ]
#           },
#           {
#             "id": "Generic Cladding & Finishes",
#             "children": [
#               {
#                 "id": "Generic Internal Cladding & Finishes"
#               },
#               {
#                 "id": "Generic External Cladding & Finishes"
#               }
#             ]
#           },
#           {
#             "id": "Generic Insulation Material",
#             "children": [
#               {
#                 "id": "Generic Waterproofing"
#               },
#               {
#                 "id": "Generic Thermal Insulation"
#               },
#               {
#                 "id": "Generic Fireproofing"
#               },
#               {
#                 "id": "Generic Air Gap"
#               }
#             ]
#           },
#           {
#             "id": "Generic Masonry",
#             "children": [
#               {
#                 "id": "Generic Brick"
#               },
#               {
#                 "id": "Generic Block"
#               }
#             ]
#           },
#           {
#             "id": "Generic Filler Material",
#             "children": [
#               {
#                 "id": "Generic Prefab Filler"
#               },
#               {
#                 "id": "Generic In-situ Filler"
#               }
#             ]
#           },
#           {
#             "id": "Generic Interior Material"
#           }
#         ]
#       },
#       {
#         "id": "Ceramic",
#         "children": [
#           {
#             "id": "Ceramic Cladding & Finishes",
#             "children": [
#               {
#                 "id": "Ceramic Roof Tiles"
#               },
#               {
#                 "id": "Ceramic Floor Tiles"
#               },
#               {
#                 "id": "Ceramic Wall Tiles"
#               }
#             ]
#           },
#           {
#             "id": "Ceramic Fitting"
#           },
#           {
#             "id": "Ceramic Masonry"
#           }
#         ]
#       },
#       {
#         "id": "Concrete",
#         "children": [
#           {
#             "id": "Structural Concrete",
#             "children": [
#               {
#                 "id": "Structural In Situ Concrete"
#               },
#               {
#                 "id": "Structural Prefab Concrete"
#               }
#             ]
#           },
#           {
#             "id": "Concrete Masonry",
#             "children": [
#               {
#                 "id": "Concrete Block"
#               },
#               {
#                 "id": "Concrete Brick"
#               }
#             ]
#           },
#           {
#             "id": "Concrete Cladding & Finishes",
#             "children": [
#               {
#                 "id": "Sprayed Concrete"
#               },
#               {
#                 "id": "Concrete Roofing Tile"
#               },
#               {
#                 "id": "Concrete Floor Tile"
#               },
#               {
#                 "id": "Concrete Floor Layer"
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "id": "Burnt Clay",
#         "children": [
#           {
#             "id": "Burnt Clay Masonry",
#             "children": [
#               {
#                 "id": "Clay Brick"
#               },
#               {
#                 "id": "Clay Block"
#               },
#               {
#                 "id": "Straw Bale"
#               }
#             ]
#           },
#           {
#             "id": "Burnt Clay Cladding & Finishes",
#             "children": [
#               {
#                 "id": "Clay Roof Tile"
#               },
#               {
#                 "id": "Clay Floor Finish"
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "id": "Glass",
#         "children": [
#           {
#             "id": "Glazing Glass"
#           },
#           {
#             "id": "Glass Block"
#           },
#           {
#             "id": "Structural Glass"
#           },
#           {
#             "id": "Glass Wool"
#           }
#         ]
#       },
#       {
#         "id": "Gypsum",
#         "children": [
#           {
#             "id": "Gypsum Masonry",
#             "children": [
#               {
#                 "id": "Gypsum Bricks"
#               },
#               {
#                 "id": "Gypsum Blocks"
#               }
#             ]
#           },
#           {
#             "id": "Gypsum Cladding & Finishes",
#             "children": [
#               {
#                 "id": "Gypsum Plaster"
#               }
#             ]
#           },
#           {
#             "id": "Gypsum Partitioning"
#           }
#         ]
#       },
#       {
#         "id": "Metal",
#         "children": [
#           {
#             "id": "Structural Metal",
#             "children": [
#               {
#                 "id": "Metal Framing"
#               },
#               {
#                 "id": "Metal Carcassing"
#               }
#             ]
#           },
#           {
#             "id": "Metal Cladding & Finishes",
#             "children": [
#               {
#                 "id": "Sheet Metal"
#               },
#               {
#                 "id": "Metal Finish"
#               }
#             ]
#           },
#           {
#             "id": "Metal Insulation"
#           },
#           {
#             "id": "Ironmongery"
#           },
#           {
#             "id": "Plumbing Metal"
#           }
#         ]
#       },
#       {
#         "id": "Mineral",
#         "children": [
#           {
#             "id": "Mineral Thermal Insulation"
#           },
#           {
#             "id": "Mineral Waterproofing"
#           },
#           {
#             "id": "Mineral Coating & Finishes",
#             "children": [
#               {
#                 "id": "Mineral Plaster"
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "id": "Nature",
#         "children": [
#           {
#             "id": "Air"
#           },
#           {
#             "id": "Terrain Materials"
#           },
#           {
#             "id": "Flora & Fauna Material"
#           },
#           {
#             "id": "Paving Material"
#           },
#           {
#             "id": "Body of Water"
#           }
#         ]
#       },
#       {
#         "id": "Plastic",
#         "children": [
#           {
#             "id": "Plastic Glazing"
#           },
#           {
#             "id": "Plastic Thermal Insulation"
#           },
#           {
#             "id": "Plastic Waterproofing"
#           },
#           {
#             "id": "Plastic Sealants"
#           },
#           {
#             "id": "Plastic Claddings & Finishes"
#           }
#         ]
#       },
#       {
#         "id": "Stone",
#         "children": [
#           {
#             "id": "Stone Masonry",
#             "children": [
#               {
#                 "id": "Stones - Fabricated",
#                 "children": [
#                   {
#                     "id": "Stone Bricks"
#                   },
#                   {
#                     "id": "Stone Blocks"
#                   }
#                 ]
#               },
#               {
#                 "id": "Stones - Ashlar & Rubble",
#                 "children": [
#                   {
#                     "id": "Natural Stones"
#                   },
#                   {
#                     "id": "Cast Stones"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "id": "Stone Cladding & Finishes",
#             "children": [
#               {
#                 "id": "Stone - Flooring"
#               },
#               {
#                 "id": "Stone - Wall Cladding"
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "id": "Wood",
#         "children": [
#           {
#             "id": "Structural Timber",
#             "children": [
#               {
#                 "id": "Framing Timber",
#                 "children": [
#                   {
#                     "id": "Glued-Laminated Timber"
#                   }
#                 ]
#               },
#               {
#                 "id": "Carcassing Timber",
#                 "children": [
#                   {
#                     "id": "Plywood"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "id": "Timber Cladding & Finishes",
#             "children": [
#               {
#                 "id": "Wood Flooring"
#               },
#               {
#                 "id": "Wood Shingles"
#               },
#               {
#                 "id": "Wood Wall Boarding"
#               },
#               {
#                 "id": "Practicle Board"
#               },
#               {
#                 "id": "Fibreboard"
#               }
#             ]
#           },
#           {
#             "id": "Interior & Furniture Wood",
#             "children": [
#               {
#                 "id": "Softwood"
#               },
#               {
#                 "id": "Hardwood"
#               }
#             ]
#           },
#           {
#             "id": "Wood Fills & Insulations",
#             "children": [
#               {
#                 "id": "Wood Fibre"
#               },
#               {
#                 "id": "Wood Wool"
#               },
#               {
#                 "id": "Sawdust"
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "id": "Coverings",
#         "children": [
#           {
#             "id": "Textiles"
#           },
#           {
#             "id": "Papers"
#           },
#           {
#             "id": "Leather"
#           }
#         ]
#       }
#     ]
#   }
# ]

# %% [markdown]
# Process config and apply

# %%
def apply_new_config(element_tree, new_config):
    def find_config_node(config, node_id):
        for item in config:
            if item['id'] == node_id:
                return item
            if 'children' in item:
                result = find_config_node(item['children'], node_id)
                if result:
                    return result
        return None

    def process_node(node, parent_properties=None):
        if parent_properties is None:
            parent_properties = set()

        # Find the corresponding config for this node
        config_node = find_config_node(new_config, node['id'])

        # Start with parent properties
        node['properties'] = set(parent_properties)

        if config_node:
            # Remove properties that should not be inherited
            if 'not_inherited_from' in config_node:
                node['properties'] -= set(config_node['not_inherited_from'])

            # Add new properties
            if 'new_properties' in config_node:
                node['properties'] |= set(config_node['new_properties'])

        # Process children after the current node is fully processed
        for child in node['children']:
            process_node(child, node['properties'])

        # Remove properties that should never be inherited to children
        if config_node and 'never_inherit_to' in config_node:
            for child in node['children']:
                child['properties'] -= set(config_node['never_inherit_to'])

    # Process each root node
    for root_node in element_tree:
        process_node(root_node)

# Load the new configuration
with open('config.json', 'r') as f:
    new_config = json.load(f)

# Apply the new configuration to the element tree
apply_new_config(element_tree, new_config)

print("New configuration applied to element tree.")

# Function to convert sets to lists for JSON serialization
def sets_to_lists(obj):
    if isinstance(obj, dict):
        return {k: sets_to_lists(v) for k, v in obj.items()}
    elif isinstance(obj, list):
        return [sets_to_lists(v) for v in obj]
    elif isinstance(obj, set):
        return list(obj)
    else:
        return obj

# Print the updated element tree
print(json.dumps(sets_to_lists(element_tree), indent=2))

# Optionally, save the updated element tree to a file
with open('updated_element_tree.json', 'w') as f:
    json.dump(sets_to_lists(element_tree), f, indent=2)
# Out:
# New configuration applied to element tree.
# [
#   {
#     "id": "Site",
#     "children": [
#       {
#         "id": "Geographic Element",
#         "children": [
#           {
#             "id": "Terrain",
#             "children": [],
#             "properties": []
#           },
#           {
#             "id": "Site Geometry",
#             "children": [],
#             "properties": []
#           },
#           {
#             "id": "Flora & Fauna",
#             "children": [],
#             "properties": []
#           }
#         ],
#         "properties": []
#       },
#       {
#         "id": "Massing",
#         "children": [
#           {
#             "id": "Morph",
#             "children": [],
#             "properties": []
#           }
#         ],
#         "properties": []
#       },
#       {
#         "id": "Civil Element",
#         "children": [],
#         "properties": []
#       }
#     ],
#     "properties": []
#   },
#   {
#     "id": "Space",
#     "children": [
#       {
#         "id": "External Space",
#         "children": [
#           {
#             "id": "Parking Space",
#             "children": [],
#             "properties": [
#               "Fire exit space",
#               "Finishing - Floors",
#               "Finishing - Walls",
#               "Wall finish thickness (requirement)",
#               "Access - accessibility for the disabled",
#               "Risk factor",
#               "Usage type of space",
#               "Status (Space and Zone)",
#               "Number of expected occupants",
#               "Phasing",
#               "Sprinkling",
#               "Documentation",
#               "Finishing - Ceilings",
#               "Access - Accessible to the public",
#               "Finishing - Baseboards",
#               "Passage height required"
#             ]
#           }
#         ],
#         "properties": [
#           "Fire exit space",
#           "Finishing - Floors",
#           "Finishing - Walls",
#           "Wall finish thickness (requirement)",
#           "Access - accessibility for the disabled",
#           "Risk factor",
#           "Usage type of space",
#           "Status (Space and Zone)",
#           "Number of expected occupants",
#           "Phasing",
#           "Sprinkling",
#           "Documentation",
#           "Finishing - Ceilings",
#           "Access - Accessible to the public",
#           "Finishing - Baseboards",
#           "Passage height required"
#         ]
#       },
#       {
#         "id": "Internal Space",
#         "children": [
#           {
#             "id": "Access Space",
#             "children": [],
#             "properties": [
#               "Fire exit space",
#               "Finishing - Floors",
#               "Finishing - Walls",
#               "Wall finish thickness (requirement)",
#               "Access - accessibility for the disabled",
#               "Risk factor",
#               "Usage type of space",
#               "Status (Space and Zone)",
#               "Number of expected occupants",
#               "Phasing",
#               "Sprinkling",
#               "Documentation",
#               "Finishing - Ceilings",
#               "Access - Accessible to the public",
#               "Finishing - Baseboards",
#               "Passage height required"
#             ]
#           },
#           {
#             "id": "Commercial Space",
#             "children": [],
#             "properties": [
#               "Fire exit space",
#               "Finishing - Floors",
#               "Finishing - Walls",
#               "Wall finish thickness (requirement)",
#               "Access - accessibility for the disabled",
#               "Risk factor",
#               "Usage type of space",
#               "Status (Space and Zone)",
#               "Number of expected occupants",
#               "Phasing",
#               "Sprinkling",
#               "Documentation",
#               "Finishing - Ceilings",
#               "Access - Accessible to the public",
#               "Finishing - Baseboards",
#               "Passage height required"
#             ]
#           },
#           {
#             "id": "Communication Space",
#             "children": [],
#             "properties": [
#               "Fire exit space",
#               "Finishing - Floors",
#               "Finishing - Walls",
#               "Wall finish thickness (requirement)",
#               "Access - accessibility for the disabled",
#               "Risk factor",
#               "Usage type of space",
#               "Status (Space and Zone)",
#               "Number of expected occupants",
#               "Phasing",
#               "Sprinkling",
#               "Documentation",
#               "Finishing - Ceilings",
#               "Access - Accessible to the public",
#               "Finishing - Baseboards",
#               "Passage height required"
#             ]
#           },
#           {
#             "id": "Cultural Space",
#             "children": [],
#             "properties": [
#               "Fire exit space",
#               "Finishing - Floors",
#               "Finishing - Walls",
#               "Wall finish thickness (requirement)",
#               "Access - accessibility for the disabled",
#               "Risk factor",
#               "Usage type of space",
#               "Status (Space and Zone)",
#               "Number of expected occupants",
#               "Phasing",
#               "Sprinkling",
#               "Documentation",
#               "Finishing - Ceilings",
#               "Access - Accessible to the public",
#               "Finishing - Baseboards",
#               "Passage height required"
#             ]
#           },
#           {
#             "id": "Educational Space",
#             "children": [],
#             "properties": [
#               "Fire exit space",
#               "Finishing - Floors",
#               "Finishing - Walls",
#               "Wall finish thickness (requirement)",
#               "Access - accessibility for the disabled",
#               "Risk factor",
#               "Usage type of space",
#               "Status (Space and Zone)",
#               "Number of expected occupants",
#               "Phasing",
#               "Sprinkling",
#               "Documentation",
#               "Finishing - Ceilings",
#               "Access - Accessible to the public",
#               "Finishing - Baseboards",
#               "Passage height required"
#             ]
#           },
#           {
#             "id": "Equipment Space",
#             "children": [],
#             "properties": [
#               "Fire exit space",
#               "Finishing - Floors",
#               "Finishing - Walls",
#               "Wall finish thickness (requirement)",
#               "Access - accessibility for the disabled",
#               "Risk factor",
#               "Usage type of space",
#               "Status (Space and Zone)",
#               "Number of expected occupants",
#               "Phasing",
#               "Sprinkling",
#               "Documentation",
#               "Finishing - Ceilings",
#               "Access - Accessible to the public",
#               "Finishing - Baseboards",
#               "Passage height required"
#             ]
#           },
#           {
#             "id": "Medical Space",
#             "children": [],
#             "properties": [
#               "Fire exit space",
#               "Finishing - Floors",
#               "Finishing - Walls",
#               "Wall finish thickness (requirement)",
#               "Access - accessibility for the disabled",
#               "Risk factor",
#               "Usage type of space",
#               "Status (Space and Zone)",
#               "Number of expected occupants",
#               "Phasing",
#               "Sprinkling",
#               "Documentation",
#               "Finishing - Ceilings",
#               "Access - Accessible to the public",
#               "Finishing - Baseboards",
#               "Passage height required"
#             ]
#           },
#           {
#             "id": "Office Space",
#             "children": [],
#             "properties": [
#               "Fire exit space",
#               "Finishing - Floors",
#               "Finishing - Walls",
#               "Wall finish thickness (requirement)",
#               "Access - accessibility for the disabled",
#               "Risk factor",
#               "Usage type of space",
#               "Status (Space and Zone)",
#               "Number of expected occupants",
#               "Phasing",
#               "Sprinkling",
#               "Documentation",
#               "Finishing - Ceilings",
#               "Access - Accessible to the public",
#               "Finishing - Baseboards",
#               "Passage height required"
#             ]
#           },
#           {
#             "id": "Production Space",
#             "children": [],
#             "properties": [
#               "Fire exit space",
#               "Finishing - Floors",
#               "Finishing - Walls",
#               "Wall finish thickness (requirement)",
#               "Access - accessibility for the disabled",
#               "Risk factor",
#               "Usage type of space",
#               "Status (Space and Zone)",
#               "Number of expected occupants",
#               "Phasing",
#               "Sprinkling",
#               "Documentation",
#               "Finishing - Ceilings",
#               "Access - Accessible to the public",
#               "Finishing - Baseboards",
#               "Passage height required"
#             ]
#           },
#           {
#             "id": "Recreational Space",
#             "children": [],
#             "properties": [
#               "Fire exit space",
#               "Finishing - Floors",
#               "Finishing - Walls",
#               "Wall finish thickness (requirement)",
#               "Access - accessibility for the disabled",
#               "Risk factor",
#               "Usage type of space",
#               "Status (Space and Zone)",
#               "Number of expected occupants",
#               "Phasing",
#               "Sprinkling",
#               "Documentation",
#               "Finishing - Ceilings",
#               "Access - Accessible to the public",
#               "Finishing - Baseboards",
#               "Passage height required"
#             ]
#           },
#           {
#             "id": "Research Space",
#             "children": [],
#             "properties": [
#               "Fire exit space",
#               "Finishing - Floors",
#               "Finishing - Walls",
#               "Wall finish thickness (requirement)",
#               "Access - accessibility for the disabled",
#               "Risk factor",
#               "Usage type of space",
#               "Status (Space and Zone)",
#               "Number of expected occupants",
#               "Phasing",
#               "Sprinkling",
#               "Documentation",
#               "Finishing - Ceilings",
#               "Access - Accessible to the public",
#               "Finishing - Baseboards",
#               "Passage height required"
#             ]
#           },
#           {
#             "id": "Residential Space",
#             "children": [],
#             "properties": [
#               "Fire exit space",
#               "Finishing - Floors",
#               "Finishing - Walls",
#               "Wall finish thickness (requirement)",
#               "Access - accessibility for the disabled",
#               "Risk factor",
#               "Usage type of space",
#               "Status (Space and Zone)",
#               "Number of expected occupants",
#               "Phasing",
#               "Sprinkling",
#               "Documentation",
#               "Finishing - Ceilings",
#               "Access - Accessible to the public",
#               "Finishing - Baseboards",
#               "Passage height required"
#             ]
#           },
#           {
#             "id": "Storage Space",
#             "children": [],
#             "properties": [
#               "Fire exit space",
#               "Finishing - Floors",
#               "Finishing - Walls",
#               "Wall finish thickness (requirement)",
#               "Access - accessibility for the disabled",
#               "Risk factor",
#               "Usage type of space",
#               "Status (Space and Zone)",
#               "Number of expected occupants",
#               "Phasing",
#               "Sprinkling",
#               "Documentation",
#               "Finishing - Ceilings",
#               "Access - Accessible to the public",
#               "Finishing - Baseboards",
#               "Passage height required"
#             ]
#           },
#           {
#             "id": "Transport Space",
#             "children": [],
#             "properties": [
#               "Fire exit space",
#               "Finishing - Floors",
#               "Finishing - Walls",
#               "Wall finish thickness (requirement)",
#               "Access - accessibility for the disabled",
#               "Risk factor",
#               "Usage type of space",
#               "Status (Space and Zone)",
#               "Number of expected occupants",
#               "Phasing",
#               "Sprinkling",
#               "Documentation",
#               "Finishing - Ceilings",
#               "Access - Accessible to the public",
#               "Finishing - Baseboards",
#               "Passage height required"
#             ]
#           },
#           {
#             "id": "General Floor Area Space",
#             "children": [],
#             "properties": [
#               "Fire exit space",
#               "Finishing - Floors",
#               "Finishing - Walls",
#               "Wall finish thickness (requirement)",
#               "Access - accessibility for the disabled",
#               "Risk factor",
#               "Usage type of space",
#               "Status (Space and Zone)",
#               "Number of expected occupants",
#               "Phasing",
#               "Sprinkling",
#               "Documentation",
#               "Finishing - Ceilings",
#               "Access - Accessible to the public",
#               "Finishing - Baseboards",
#               "Passage height required"
#             ]
#           }
#         ],
#         "properties": [
#           "Fire exit space",
#           "Finishing - Floors",
#           "Finishing - Walls",
#           "Wall finish thickness (requirement)",
#           "Access - accessibility for the disabled",
#           "Risk factor",
#           "Usage type of space",
#           "Status (Space and Zone)",
#           "Number of expected occupants",
#           "Phasing",
#           "Sprinkling",
#           "Documentation",
#           "Finishing - Ceilings",
#           "Access - Accessible to the public",
#           "Finishing - Baseboards",
#           "Passage height required"
#         ]
#       }
#     ],
#     "properties": [
#       "Fire exit space",
#       "Finishing - Floors",
#       "Finishing - Walls",
#       "Wall finish thickness (requirement)",
#       "Access - accessibility for the disabled",
#       "Risk factor",
#       "Usage type of space",
#       "Status (Space and Zone)",
#       "Number of expected occupants",
#       "Phasing",
#       "Sprinkling",
#       "Documentation",
#       "Finishing - Ceilings",
#       "Access - Accessible to the public",
#       "Finishing - Baseboards",
#       "Passage height required"
#     ]
#   },
#   {
#     "id": "Elements",
#     "children": [
#       {
#         "id": "Construction Element",
#         "children": [
#           {
#             "id": "Building Element Proxy",
#             "children": [
#               {
#                 "id": "Complex Building Element Proxy",
#                 "children": [],
#                 "properties": []
#               },
#               {
#                 "id": "Element Building Element Proxy",
#                 "children": [],
#                 "properties": []
#               },
#               {
#                 "id": "Partial Building Element Proxy",
#                 "children": [],
#                 "properties": []
#               },
#               {
#                 "id": "Provision for Space",
#                 "children": [],
#                 "properties": []
#               },
#               {
#                 "id": "Provision for Void",
#                 "children": [],
#                 "properties": []
#               }
#             ],
#             "properties": []
#           },
#           {
#             "id": "Wall",
#             "children": [
#               {
#                 "id": "Elemented Wall",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Thermal Transmittance",
#                   "Documentation",
#                   "Flammability rating",
#                   "Construction method",
#                   "Fire Resistance Rating",
#                   "Reinforcement",
#                   "Work package",
#                   "Outer shell"
#                 ]
#               },
#               {
#                 "id": "Movable Wall",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Thermal Transmittance",
#                   "Documentation",
#                   "Flammability rating",
#                   "Construction method",
#                   "Fire Resistance Rating",
#                   "Reinforcement",
#                   "Work package",
#                   "Outer shell"
#                 ]
#               },
#               {
#                 "id": "Parapet Wall",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Thermal Transmittance",
#                   "Documentation",
#                   "Flammability rating",
#                   "Construction method",
#                   "Fire Resistance Rating",
#                   "Reinforcement",
#                   "Work package",
#                   "Outer shell"
#                 ]
#               },
#               {
#                 "id": "Partitioning Wall",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Thermal Transmittance",
#                   "Documentation",
#                   "Flammability rating",
#                   "Construction method",
#                   "Fire Resistance Rating",
#                   "Reinforcement",
#                   "Work package",
#                   "Outer shell"
#                 ]
#               },
#               {
#                 "id": "Plumbing Wall",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Thermal Transmittance",
#                   "Documentation",
#                   "Flammability rating",
#                   "Construction method",
#                   "Fire Resistance Rating",
#                   "Reinforcement",
#                   "Work package",
#                   "Outer shell"
#                 ]
#               },
#               {
#                 "id": "Polygonal Wall",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Thermal Transmittance",
#                   "Documentation",
#                   "Flammability rating",
#                   "Construction method",
#                   "Fire Resistance Rating",
#                   "Reinforcement",
#                   "Work package",
#                   "Outer shell"
#                 ]
#               },
#               {
#                 "id": "Shear Wall",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Thermal Transmittance",
#                   "Documentation",
#                   "Flammability rating",
#                   "Construction method",
#                   "Fire Resistance Rating",
#                   "Reinforcement",
#                   "Work package",
#                   "Outer shell"
#                 ]
#               },
#               {
#                 "id": "Solid Wall",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Thermal Transmittance",
#                   "Documentation",
#                   "Flammability rating",
#                   "Construction method",
#                   "Fire Resistance Rating",
#                   "Reinforcement",
#                   "Work package",
#                   "Outer shell"
#                 ]
#               },
#               {
#                 "id": "Standard Wall",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Thermal Transmittance",
#                   "Documentation",
#                   "Flammability rating",
#                   "Construction method",
#                   "Fire Resistance Rating",
#                   "Reinforcement",
#                   "Work package",
#                   "Outer shell"
#                 ]
#               },
#               {
#                 "id": "Thermal break (structural)",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Thermal Transmittance",
#                   "Documentation",
#                   "Flammability rating",
#                   "Construction method",
#                   "Fire Resistance Rating",
#                   "Reinforcement",
#                   "Work package",
#                   "Outer shell"
#                 ]
#               },
#               {
#                 "id": "Secant pile",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Thermal Transmittance",
#                   "Documentation",
#                   "Flammability rating",
#                   "Construction method",
#                   "Fire Resistance Rating",
#                   "Reinforcement",
#                   "Work package",
#                   "Outer shell"
#                 ]
#               },
#               {
#                 "id": "Tangeant pile",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Thermal Transmittance",
#                   "Documentation",
#                   "Flammability rating",
#                   "Construction method",
#                   "Fire Resistance Rating",
#                   "Reinforcement",
#                   "Work package",
#                   "Outer shell"
#                 ]
#               },
#               {
#                 "id": "Sheet pile",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Thermal Transmittance",
#                   "Documentation",
#                   "Flammability rating",
#                   "Construction method",
#                   "Fire Resistance Rating",
#                   "Reinforcement",
#                   "Work package",
#                   "Outer shell"
#                 ]
#               },
#               {
#                 "id": "Retaining wall",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Thermal Transmittance",
#                   "Documentation",
#                   "Flammability rating",
#                   "Construction method",
#                   "Fire Resistance Rating",
#                   "Reinforcement",
#                   "Work package",
#                   "Outer shell"
#                 ]
#               },
#               {
#                 "id": "Deepwall",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Thermal Transmittance",
#                   "Documentation",
#                   "Flammability rating",
#                   "Construction method",
#                   "Fire Resistance Rating",
#                   "Reinforcement",
#                   "Work package",
#                   "Outer shell"
#                 ]
#               },
#               {
#                 "id": "Soldier pile wall",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Thermal Transmittance",
#                   "Documentation",
#                   "Flammability rating",
#                   "Construction method",
#                   "Fire Resistance Rating",
#                   "Reinforcement",
#                   "Work package",
#                   "Outer shell"
#                 ]
#               },
#               {
#                 "id": "Combiwall",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Thermal Transmittance",
#                   "Documentation",
#                   "Flammability rating",
#                   "Construction method",
#                   "Fire Resistance Rating",
#                   "Reinforcement",
#                   "Work package",
#                   "Outer shell"
#                 ]
#               },
#               {
#                 "id": "Soilmix wall",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Thermal Transmittance",
#                   "Documentation",
#                   "Flammability rating",
#                   "Construction method",
#                   "Fire Resistance Rating",
#                   "Reinforcement",
#                   "Work package",
#                   "Outer shell"
#                 ]
#               },
#               {
#                 "id": "Cement-bentonite slurry wall",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Thermal Transmittance",
#                   "Documentation",
#                   "Flammability rating",
#                   "Construction method",
#                   "Fire Resistance Rating",
#                   "Reinforcement",
#                   "Work package",
#                   "Outer shell"
#                 ]
#               },
#               {
#                 "id": "Timbered trench",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Thermal Transmittance",
#                   "Documentation",
#                   "Flammability rating",
#                   "Construction method",
#                   "Fire Resistance Rating",
#                   "Reinforcement",
#                   "Work package",
#                   "Outer shell"
#                 ]
#               }
#             ],
#             "properties": [
#               "IFC renovation status",
#               "Thermal Conductivity",
#               "Phasing",
#               "Thermal Transmittance",
#               "Documentation",
#               "Flammability rating",
#               "Construction method",
#               "Fire Resistance Rating",
#               "Reinforcement",
#               "Work package",
#               "Outer shell"
#             ]
#           },
#           {
#             "id": "Footing",
#             "children": [
#               {
#                 "id": "Caisson Foundation",
#                 "children": [],
#                 "properties": []
#               },
#               {
#                 "id": "Footing Beam",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Documentation",
#                   "Construction method",
#                   "Reinforcement",
#                   "Work package",
#                   "Structural Function ArchiCAD - IsLoadBearing"
#                 ]
#               },
#               {
#                 "id": "Pad Footing",
#                 "children": [],
#                 "properties": []
#               },
#               {
#                 "id": "Pile Cap",
#                 "children": [],
#                 "properties": []
#               },
#               {
#                 "id": "Strip Footing",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Documentation",
#                   "Construction method",
#                   "Reinforcement",
#                   "Work package",
#                   "Structural Function ArchiCAD - IsLoadBearing"
#                 ]
#               }
#             ],
#             "properties": []
#           },
#           {
#             "id": "Column",
#             "children": [
#               {
#                 "id": "Column Segment",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Documentation",
#                   "Flammability rating",
#                   "Construction method",
#                   "Fire Resistance Rating",
#                   "Reinforcement",
#                   "Work package",
#                   "Outer shell"
#                 ]
#               },
#               {
#                 "id": "Pilaster",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Documentation",
#                   "Flammability rating",
#                   "Construction method",
#                   "Fire Resistance Rating",
#                   "Reinforcement",
#                   "Work package",
#                   "Outer shell"
#                 ]
#               }
#             ],
#             "properties": [
#               "IFC renovation status",
#               "Thermal Conductivity",
#               "Phasing",
#               "Documentation",
#               "Flammability rating",
#               "Construction method",
#               "Fire Resistance Rating",
#               "Reinforcement",
#               "Work package",
#               "Outer shell"
#             ]
#           },
#           {
#             "id": "Pile",
#             "children": [
#               {
#                 "id": "Bored Pile",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Documentation",
#                   "Construction method",
#                   "Reinforcement",
#                   "Work package",
#                   "Structural Function ArchiCAD - IsLoadBearing"
#                 ]
#               },
#               {
#                 "id": "Cohesion Pile",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Documentation",
#                   "Construction method",
#                   "Reinforcement",
#                   "Work package",
#                   "Structural Function ArchiCAD - IsLoadBearing"
#                 ]
#               },
#               {
#                 "id": "Driven Pile",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Documentation",
#                   "Construction method",
#                   "Reinforcement",
#                   "Work package",
#                   "Structural Function ArchiCAD - IsLoadBearing"
#                 ]
#               },
#               {
#                 "id": "Friction Pile",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Documentation",
#                   "Construction method",
#                   "Reinforcement",
#                   "Work package",
#                   "Structural Function ArchiCAD - IsLoadBearing"
#                 ]
#               },
#               {
#                 "id": "Jetgrouting Pile",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Documentation",
#                   "Construction method",
#                   "Reinforcement",
#                   "Work package",
#                   "Structural Function ArchiCAD - IsLoadBearing"
#                 ]
#               },
#               {
#                 "id": "Support Pile",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Documentation",
#                   "Construction method",
#                   "Reinforcement",
#                   "Work package",
#                   "Structural Function ArchiCAD - IsLoadBearing"
#                 ]
#               },
#               {
#                 "id": "Screw Pile",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Documentation",
#                   "Construction method",
#                   "Reinforcement",
#                   "Work package",
#                   "Structural Function ArchiCAD - IsLoadBearing"
#                 ]
#               },
#               {
#                 "id": "Soil Mix",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Documentation",
#                   "Construction method",
#                   "Reinforcement",
#                   "Work package",
#                   "Structural Function ArchiCAD - IsLoadBearing"
#                 ]
#               },
#               {
#                 "id": "Stone columns",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Documentation",
#                   "Construction method",
#                   "Reinforcement",
#                   "Work package",
#                   "Structural Function ArchiCAD - IsLoadBearing"
#                 ]
#               },
#               {
#                 "id": "Rigid inclusions",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Documentation",
#                   "Construction method",
#                   "Reinforcement",
#                   "Work package",
#                   "Structural Function ArchiCAD - IsLoadBearing"
#                 ]
#               }
#             ],
#             "properties": [
#               "IFC renovation status",
#               "Thermal Conductivity",
#               "Phasing",
#               "Documentation",
#               "Construction method",
#               "Reinforcement",
#               "Work package",
#               "Structural Function ArchiCAD - IsLoadBearing"
#             ]
#           },
#           {
#             "id": "Beam",
#             "children": [
#               {
#                 "id": "Beam Segment",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Thermal Transmittance",
#                   "Documentation",
#                   "Flammability rating",
#                   "Construction method",
#                   "Fire Resistance Rating",
#                   "Reinforcement",
#                   "Work package",
#                   "Outer shell"
#                 ]
#               },
#               {
#                 "id": "Joist",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Thermal Transmittance",
#                   "Documentation",
#                   "Flammability rating",
#                   "Construction method",
#                   "Fire Resistance Rating",
#                   "Reinforcement",
#                   "Work package",
#                   "Outer shell"
#                 ]
#               },
#               {
#                 "id": "Hollowcore",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Thermal Transmittance",
#                   "Documentation",
#                   "Flammability rating",
#                   "Construction method",
#                   "Fire Resistance Rating",
#                   "Reinforcement",
#                   "Work package",
#                   "Outer shell"
#                 ]
#               },
#               {
#                 "id": "Lintel",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Thermal Transmittance",
#                   "Documentation",
#                   "Flammability rating",
#                   "Construction method",
#                   "Fire Resistance Rating",
#                   "Reinforcement",
#                   "Work package",
#                   "Outer shell"
#                 ]
#               },
#               {
#                 "id": "Spandrel",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Thermal Transmittance",
#                   "Documentation",
#                   "Flammability rating",
#                   "Construction method",
#                   "Fire Resistance Rating",
#                   "Reinforcement",
#                   "Work package",
#                   "Outer shell"
#                 ]
#               },
#               {
#                 "id": "T-Beam",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Thermal Transmittance",
#                   "Documentation",
#                   "Flammability rating",
#                   "Construction method",
#                   "Fire Resistance Rating",
#                   "Reinforcement",
#                   "Work package",
#                   "Outer shell"
#                 ]
#               },
#               {
#                 "id": "Ring beam",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Thermal Transmittance",
#                   "Documentation",
#                   "Flammability rating",
#                   "Construction method",
#                   "Fire Resistance Rating",
#                   "Reinforcement",
#                   "Work package",
#                   "Outer shell"
#                 ]
#               },
#               {
#                 "id": "Spandrel beam",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Thermal Transmittance",
#                   "Documentation",
#                   "Flammability rating",
#                   "Construction method",
#                   "Fire Resistance Rating",
#                   "Reinforcement",
#                   "Work package",
#                   "Outer shell"
#                 ]
#               }
#             ],
#             "properties": [
#               "IFC renovation status",
#               "Thermal Conductivity",
#               "Phasing",
#               "Thermal Transmittance",
#               "Documentation",
#               "Flammability rating",
#               "Construction method",
#               "Fire Resistance Rating",
#               "Reinforcement",
#               "Work package",
#               "Outer shell"
#             ]
#           },
#           {
#             "id": "Slab",
#             "children": [
#               {
#                 "id": "Floor Slab",
#                 "children": [],
#                 "properties": [
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Thermal Transmittance",
#                   "Documentation",
#                   "Construction method",
#                   "Fire Resistance Rating",
#                   "Reinforcement",
#                   "Work package",
#                   "Outer shell"
#                 ]
#               },
#               {
#                 "id": "Roof Slab",
#                 "children": [],
#                 "properties": [
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Thermal Transmittance",
#                   "Documentation",
#                   "Construction method",
#                   "Fire Resistance Rating",
#                   "Reinforcement",
#                   "Work package",
#                   "Outer shell"
#                 ]
#               },
#               {
#                 "id": "Landing Slab",
#                 "children": [],
#                 "properties": [
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Thermal Transmittance",
#                   "Documentation",
#                   "Construction method",
#                   "Fire Resistance Rating",
#                   "Reinforcement",
#                   "Work package",
#                   "Outer shell"
#                 ]
#               },
#               {
#                 "id": "Base Slab",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Thermal Transmittance",
#                   "Documentation",
#                   "Construction method",
#                   "Reinforcement",
#                   "Work package",
#                   "Outer shell"
#                 ]
#               }
#             ],
#             "properties": [
#               "Thermal Conductivity",
#               "Phasing",
#               "Thermal Transmittance",
#               "Documentation",
#               "Construction method",
#               "Fire Resistance Rating",
#               "Reinforcement",
#               "Work package",
#               "Outer shell"
#             ]
#           },
#           {
#             "id": "Roof",
#             "children": [
#               {
#                 "id": "Flat Roof",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Thermal Transmittance",
#                   "Documentation",
#                   "Flammability rating",
#                   "Construction method",
#                   "Fire Resistance Rating",
#                   "Reinforcement",
#                   "Work package",
#                   "Outer shell",
#                   "Structural Function ArchiCAD - IsLoadBearing"
#                 ]
#               },
#               {
#                 "id": "Shed Roof",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Thermal Transmittance",
#                   "Documentation",
#                   "Flammability rating",
#                   "Construction method",
#                   "Fire Resistance Rating",
#                   "Reinforcement",
#                   "Work package",
#                   "Outer shell",
#                   "Structural Function ArchiCAD - IsLoadBearing"
#                 ]
#               },
#               {
#                 "id": "Gable Roof",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Thermal Transmittance",
#                   "Documentation",
#                   "Flammability rating",
#                   "Construction method",
#                   "Fire Resistance Rating",
#                   "Reinforcement",
#                   "Work package",
#                   "Outer shell",
#                   "Structural Function ArchiCAD - IsLoadBearing"
#                 ]
#               },
#               {
#                 "id": "Hip Roof",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Thermal Transmittance",
#                   "Documentation",
#                   "Flammability rating",
#                   "Construction method",
#                   "Fire Resistance Rating",
#                   "Reinforcement",
#                   "Work package",
#                   "Outer shell",
#                   "Structural Function ArchiCAD - IsLoadBearing"
#                 ]
#               },
#               {
#                 "id": "Hipped Gable Roof",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Thermal Transmittance",
#                   "Documentation",
#                   "Flammability rating",
#                   "Construction method",
#                   "Fire Resistance Rating",
#                   "Reinforcement",
#                   "Work package",
#                   "Outer shell",
#                   "Structural Function ArchiCAD - IsLoadBearing"
#                 ]
#               },
#               {
#                 "id": "Gambrel Roof",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Thermal Transmittance",
#                   "Documentation",
#                   "Flammability rating",
#                   "Construction method",
#                   "Fire Resistance Rating",
#                   "Reinforcement",
#                   "Work package",
#                   "Outer shell",
#                   "Structural Function ArchiCAD - IsLoadBearing"
#                 ]
#               },
#               {
#                 "id": "Mansard Roof",
#                 "children": [],
#                 "properties": [
#                   "IFC renovation status",
#                   "Thermal Conductivity",
#                   "Phasing",
#                   "Thermal Transmittance",
#                   "Documentation",
#                   "Flammability rating",
#                   "Construction method",
#                   "Fire Resistance Rating",
#                   "Reinforcement",
#                   "Work package",
#                   "Outer shell",
#                   "Structural Function ArchiCAD - IsLoadBearing"
#                 ]
#               },
#               {
# ...
#       },
#       {
#         "id": "Finishes",
#         "children": [],
#         "properties": []
#       }
#     ],
#     "properties": []
#   },
#   {
#     "id": "Materials",
#     "children": [
#       {
#         "id": "Generic Material",
#         "children": [
#           {
#             "id": "Generic Structural Material",
#             "children": [
#               {
#                 "id": "Generic Prefabricated Material",
#                 "children": [],
#                 "properties": []
#               },
#               {
#                 "id": "Generic In-situ Material",
#                 "children": [],
#                 "properties": []
#               }
#             ],
#             "properties": []
#           },
#           {
#             "id": "Generic Cladding & Finishes",
#             "children": [
#               {
#                 "id": "Generic Internal Cladding & Finishes",
#                 "children": [],
#                 "properties": []
#               },
#               {
#                 "id": "Generic External Cladding & Finishes",
#                 "children": [],
#                 "properties": []
#               }
#             ],
#             "properties": []
#           },
#           {
#             "id": "Generic Insulation Material",
#             "children": [
#               {
#                 "id": "Generic Waterproofing",
#                 "children": [],
#                 "properties": []
#               },
#               {
#                 "id": "Generic Thermal Insulation",
#                 "children": [],
#                 "properties": []
#               },
#               {
#                 "id": "Generic Fireproofing",
#                 "children": [],
#                 "properties": []
#               },
#               {
#                 "id": "Generic Air Gap",
#                 "children": [],
#                 "properties": []
#               }
#             ],
#             "properties": []
#           },
#           {
#             "id": "Generic Masonry",
#             "children": [
#               {
#                 "id": "Generic Brick",
#                 "children": [],
#                 "properties": []
#               },
#               {
#                 "id": "Generic Block",
#                 "children": [],
#                 "properties": []
#               }
#             ],
#             "properties": []
#           },
#           {
#             "id": "Generic Filler Material",
#             "children": [
#               {
#                 "id": "Generic Prefab Filler",
#                 "children": [],
#                 "properties": []
#               },
#               {
#                 "id": "Generic In-situ Filler",
#                 "children": [],
#                 "properties": []
#               }
#             ],
#             "properties": []
#           },
#           {
#             "id": "Generic Interior Material",
#             "children": [],
#             "properties": []
#           }
#         ],
#         "properties": []
#       },
#       {
#         "id": "Ceramic",
#         "children": [
#           {
#             "id": "Ceramic Cladding & Finishes",
#             "children": [
#               {
#                 "id": "Ceramic Roof Tiles",
#                 "children": [],
#                 "properties": []
#               },
#               {
#                 "id": "Ceramic Floor Tiles",
#                 "children": [],
#                 "properties": []
#               },
#               {
#                 "id": "Ceramic Wall Tiles",
#                 "children": [],
#                 "properties": []
#               }
#             ],
#             "properties": []
#           },
#           {
#             "id": "Ceramic Fitting",
#             "children": [],
#             "properties": []
#           },
#           {
#             "id": "Ceramic Masonry",
#             "children": [],
#             "properties": []
#           }
#         ],
#         "properties": []
#       },
#       {
#         "id": "Concrete",
#         "children": [
#           {
#             "id": "Structural Concrete",
#             "children": [
#               {
#                 "id": "Structural In Situ Concrete",
#                 "children": [],
#                 "properties": []
#               },
#               {
#                 "id": "Structural Prefab Concrete",
#                 "children": [],
#                 "properties": []
#               }
#             ],
#             "properties": []
#           },
#           {
#             "id": "Concrete Masonry",
#             "children": [
#               {
#                 "id": "Concrete Block",
#                 "children": [],
#                 "properties": []
#               },
#               {
#                 "id": "Concrete Brick",
#                 "children": [],
#                 "properties": []
#               }
#             ],
#             "properties": []
#           },
#           {
#             "id": "Concrete Cladding & Finishes",
#             "children": [
#               {
#                 "id": "Sprayed Concrete",
#                 "children": [],
#                 "properties": []
#               },
#               {
#                 "id": "Concrete Roofing Tile",
#                 "children": [],
#                 "properties": []
#               },
#               {
#                 "id": "Concrete Floor Tile",
#                 "children": [],
#                 "properties": []
#               },
#               {
#                 "id": "Concrete Floor Layer",
#                 "children": [],
#                 "properties": []
#               }
#             ],
#             "properties": []
#           }
#         ],
#         "properties": []
#       },
#       {
#         "id": "Burnt Clay",
#         "children": [
#           {
#             "id": "Burnt Clay Masonry",
#             "children": [
#               {
#                 "id": "Clay Brick",
#                 "children": [],
#                 "properties": []
#               },
#               {
#                 "id": "Clay Block",
#                 "children": [],
#                 "properties": []
#               },
#               {
#                 "id": "Straw Bale",
#                 "children": [],
#                 "properties": []
#               }
#             ],
#             "properties": []
#           },
#           {
#             "id": "Burnt Clay Cladding & Finishes",
#             "children": [
#               {
#                 "id": "Clay Roof Tile",
#                 "children": [],
#                 "properties": []
#               },
#               {
#                 "id": "Clay Floor Finish",
#                 "children": [],
#                 "properties": []
#               }
#             ],
#             "properties": []
#           }
#         ],
#         "properties": []
#       },
#       {
#         "id": "Glass",
#         "children": [
#           {
#             "id": "Glazing Glass",
#             "children": [],
#             "properties": []
#           },
#           {
#             "id": "Glass Block",
#             "children": [],
#             "properties": []
#           },
#           {
#             "id": "Structural Glass",
#             "children": [],
#             "properties": []
#           },
#           {
#             "id": "Glass Wool",
#             "children": [],
#             "properties": []
#           }
#         ],
#         "properties": []
#       },
#       {
#         "id": "Gypsum",
#         "children": [
#           {
#             "id": "Gypsum Masonry",
#             "children": [
#               {
#                 "id": "Gypsum Bricks",
#                 "children": [],
#                 "properties": []
#               },
#               {
#                 "id": "Gypsum Blocks",
#                 "children": [],
#                 "properties": []
#               }
#             ],
#             "properties": []
#           },
#           {
#             "id": "Gypsum Cladding & Finishes",
#             "children": [
#               {
#                 "id": "Gypsum Plaster",
#                 "children": [],
#                 "properties": []
#               }
#             ],
#             "properties": []
#           },
#           {
#             "id": "Gypsum Partitioning",
#             "children": [],
#             "properties": []
#           }
#         ],
#         "properties": []
#       },
#       {
#         "id": "Metal",
#         "children": [
#           {
#             "id": "Structural Metal",
#             "children": [
#               {
#                 "id": "Metal Framing",
#                 "children": [],
#                 "properties": []
#               },
#               {
#                 "id": "Metal Carcassing",
#                 "children": [],
#                 "properties": []
#               }
#             ],
#             "properties": []
#           },
#           {
#             "id": "Metal Cladding & Finishes",
#             "children": [
#               {
#                 "id": "Sheet Metal",
#                 "children": [],
#                 "properties": []
#               },
#               {
#                 "id": "Metal Finish",
#                 "children": [],
#                 "properties": []
#               }
#             ],
#             "properties": []
#           },
#           {
#             "id": "Metal Insulation",
#             "children": [],
#             "properties": []
#           },
#           {
#             "id": "Ironmongery",
#             "children": [],
#             "properties": []
#           },
#           {
#             "id": "Plumbing Metal",
#             "children": [],
#             "properties": []
#           }
#         ],
#         "properties": []
#       },
#       {
#         "id": "Mineral",
#         "children": [
#           {
#             "id": "Mineral Thermal Insulation",
#             "children": [],
#             "properties": []
#           },
#           {
#             "id": "Mineral Waterproofing",
#             "children": [],
#             "properties": []
#           },
#           {
#             "id": "Mineral Coating & Finishes",
#             "children": [
#               {
#                 "id": "Mineral Plaster",
#                 "children": [],
#                 "properties": []
#               }
#             ],
#             "properties": []
#           }
#         ],
#         "properties": []
#       },
#       {
#         "id": "Nature",
#         "children": [
#           {
#             "id": "Air",
#             "children": [],
#             "properties": []
#           },
#           {
#             "id": "Terrain Materials",
#             "children": [],
#             "properties": []
#           },
#           {
#             "id": "Flora & Fauna Material",
#             "children": [],
#             "properties": []
#           },
#           {
#             "id": "Paving Material",
#             "children": [],
#             "properties": []
#           },
#           {
#             "id": "Body of Water",
#             "children": [],
#             "properties": []
#           }
#         ],
#         "properties": []
#       },
#       {
#         "id": "Plastic",
#         "children": [
#           {
#             "id": "Plastic Glazing",
#             "children": [],
#             "properties": []
#           },
#           {
#             "id": "Plastic Thermal Insulation",
#             "children": [],
#             "properties": []
#           },
#           {
#             "id": "Plastic Waterproofing",
#             "children": [],
#             "properties": []
#           },
#           {
#             "id": "Plastic Sealants",
#             "children": [],
#             "properties": []
#           },
#           {
#             "id": "Plastic Claddings & Finishes",
#             "children": [],
#             "properties": []
#           }
#         ],
#         "properties": []
#       },
#       {
#         "id": "Stone",
#         "children": [
#           {
#             "id": "Stone Masonry",
#             "children": [
#               {
#                 "id": "Stones - Fabricated",
#                 "children": [
#                   {
#                     "id": "Stone Bricks",
#                     "children": [],
#                     "properties": []
#                   },
#                   {
#                     "id": "Stone Blocks",
#                     "children": [],
#                     "properties": []
#                   }
#                 ],
#                 "properties": []
#               },
#               {
#                 "id": "Stones - Ashlar & Rubble",
#                 "children": [
#                   {
#                     "id": "Natural Stones",
#                     "children": [],
#                     "properties": []
#                   },
#                   {
#                     "id": "Cast Stones",
#                     "children": [],
#                     "properties": []
#                   }
#                 ],
#                 "properties": []
#               }
#             ],
#             "properties": []
#           },
#           {
#             "id": "Stone Cladding & Finishes",
#             "children": [
#               {
#                 "id": "Stone - Flooring",
#                 "children": [],
#                 "properties": []
#               },
#               {
#                 "id": "Stone - Wall Cladding",
#                 "children": [],
#                 "properties": []
#               }
#             ],
#             "properties": []
#           }
#         ],
#         "properties": []
#       },
#       {
#         "id": "Wood",
#         "children": [
#           {
#             "id": "Structural Timber",
#             "children": [
#               {
#                 "id": "Framing Timber",
#                 "children": [
#                   {
#                     "id": "Glued-Laminated Timber",
#                     "children": [],
#                     "properties": []
#                   }
#                 ],
#                 "properties": []
#               },
#               {
#                 "id": "Carcassing Timber",
#                 "children": [
#                   {
#                     "id": "Plywood",
#                     "children": [],
#                     "properties": []
#                   }
#                 ],
#                 "properties": []
#               }
#             ],
#             "properties": []
#           },
#           {
#             "id": "Timber Cladding & Finishes",
#             "children": [
#               {
#                 "id": "Wood Flooring",
#                 "children": [],
#                 "properties": []
#               },
#               {
#                 "id": "Wood Shingles",
#                 "children": [],
#                 "properties": []
#               },
#               {
#                 "id": "Wood Wall Boarding",
#                 "children": [],
#                 "properties": []
#               },
#               {
#                 "id": "Practicle Board",
#                 "children": [],
#                 "properties": []
#               },
#               {
#                 "id": "Fibreboard",
#                 "children": [],
#                 "properties": []
#               }
#             ],
#             "properties": []
#           },
#           {
#             "id": "Interior & Furniture Wood",
#             "children": [
#               {
#                 "id": "Softwood",
#                 "children": [],
#                 "properties": []
#               },
#               {
#                 "id": "Hardwood",
#                 "children": [],
#                 "properties": []
#               }
#             ],
#             "properties": []
#           },
#           {
#             "id": "Wood Fills & Insulations",
#             "children": [
#               {
#                 "id": "Wood Fibre",
#                 "children": [],
#                 "properties": []
#               },
#               {
#                 "id": "Wood Wool",
#                 "children": [],
#                 "properties": []
#               },
#               {
#                 "id": "Sawdust",
#                 "children": [],
#                 "properties": []
#               }
#             ],
#             "properties": []
#           }
#         ],
#         "properties": []
#       },
#       {
#         "id": "Coverings",
#         "children": [
#           {
#             "id": "Textiles",
#             "children": [],
#             "properties": []
#           },
#           {
#             "id": "Papers",
#             "children": [],
#             "properties": []
#           },
#           {
#             "id": "Leather",
#             "children": [],
#             "properties": []
#           }
#         ],
#         "properties": []
#       }
#     ],
#     "properties": []
#   }
# ]

# %% [markdown]
# Update and save XML

# %%
try:
    from lxml import ET
except ImportError:
    import xml.etree.ElementTree as ET

def update_xml_properties(original_xml_path, updated_element_tree, output_xml_path):
    # Parse the original XML
    tree = ET.parse(original_xml_path)
    root = tree.getroot()

    # Find all PropertyDefinitionGroup elements
    prop_def_groups = root.findall('.//PropertyDefinitionGroup')
    if not prop_def_groups:
        print("Error: No PropertyDefinitionGroups found in the XML.")
        return

    # Helper function to find a node in the updated_element_tree
    def find_node(tree, node_id):
        for node in tree:
            if node['id'] == node_id:
                return node
            if 'children' in node:
                result = find_node(node['children'], node_id)
                if result:
                    return result
        return None

    # Collect all properties and their associated class IDs
    property_classes = {}
    def collect_properties(node):
        for prop in node['properties']:
            if prop not in property_classes:
                property_classes[prop] = set()
            property_classes[prop].add(node['id'])
        for child in node.get('children', []):
            collect_properties(child)

    for root_node in updated_element_tree:
        collect_properties(root_node)

    # Update existing PropertyDefinitions or create new ones
    for prop_def_group in prop_def_groups:
        prop_defs = prop_def_group.find('PropertyDefinitions')
        if prop_defs is None:
            prop_defs = ET.SubElement(prop_def_group, 'PropertyDefinitions')

        # Update existing PropertyDefinitions
        for prop_def in prop_defs.findall('PropertyDefinition'):
            prop_name = prop_def.find('Name').text
            if prop_name in property_classes:
                # Update ClassificationIDs
                class_ids_elem = prop_def.find('ClassificationIDs')
                if class_ids_elem is None:
                    class_ids_elem = ET.SubElement(prop_def, 'ClassificationIDs')
                else:
                    class_ids_elem.clear()

                for class_id in property_classes[prop_name]:
                    class_id_elem = ET.SubElement(class_ids_elem, 'ClassificationID')
                    ET.SubElement(class_id_elem, 'ItemID').text = class_id
                    ET.SubElement(class_id_elem, 'SystemIDName').text = 'ARCHICAD Classification'
                    ET.SubElement(class_id_elem, 'SystemIDVersion').text = 'v 2.0'

                # Remove this property from the dictionary as it's been processed
                del property_classes[prop_name]

        # Add new PropertyDefinitions for remaining properties
        for prop_name, class_ids in property_classes.items():
            new_prop_def = ET.SubElement(prop_defs, 'PropertyDefinition')
            ET.SubElement(new_prop_def, 'Name').text = prop_name
            ET.SubElement(new_prop_def, 'Description')
            value_desc = ET.SubElement(new_prop_def, 'ValueDescriptor', Type="SingleValueDescriptor")
            ET.SubElement(value_desc, 'ValueType').text = 'String'
            ET.SubElement(new_prop_def, 'MeasureType').text = 'Default'
            default_value = ET.SubElement(new_prop_def, 'DefaultValue')
            ET.SubElement(default_value, 'DefaultValueType').text = 'Basic'
            variant = ET.SubElement(default_value, 'Variant', Type="StringVariant")
            ET.SubElement(variant, 'Status').text = 'UserUndefined'
            class_ids_elem = ET.SubElement(new_prop_def, 'ClassificationIDs')
            for class_id in class_ids:
                class_id_elem = ET.SubElement(class_ids_elem, 'ClassificationID')
                ET.SubElement(class_id_elem, 'ItemID').text = class_id
                ET.SubElement(class_id_elem, 'SystemIDName').text = 'ARCHICAD Classification'
                ET.SubElement(class_id_elem, 'SystemIDVersion').text = 'v 2.0'

    ET.indent(tree, space="\t", level=0)
    # Save the updated XML
    tree.write(output_xml_path, encoding='UTF-8', xml_declaration=True)

    #formatter = xmlformatter.Formatter(indent="1", indent_char="\t",encoding_input="UTF-8", encoding_output="UTF-8", inline=False)
    #formatter.format_file(output_xml_path)
    
    print(f"Updated XML saved to {output_xml_path}")

# Usage
update_xml_properties('input.xml', element_tree, 'output.xml')
# Out:
# Updated XML saved to output.xml
